# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(10)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 51

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# dest [11.16565321  0.13336854]
# Avg new dist 1 0.09602252530290717 rel dist 1 0.2800662589669366 for n_states 10
# Avg new dist 5 0.004868866139369225 rel dist 5 0.01961266049684779 for n_states 10
# Time taken: 1.7947063446044922
# dest [11.23568751  0.13254854]
# Avg new dist 1 0.15676984408928513 rel dist 1 0.32865467080848054 for n_states 10
# Avg new dist 5 0.053646290632515546 rel dist 5 0.11251529458426415 for n_states 10
# Time taken: 1.7633435726165771
# dest [10.4407546   0.14248836]
# Avg new dist 1 0.22172733843255385 rel dist 1 0.4998862414503268 for n_states 10
# Avg new dist 5 0.22172733843255385 rel dist 5 0.4998862414503268 for n_states 10
# Time taken: 1.8047206401824951
# dest [11.15284344  0.13351961]
# Avg new dist 1 0.05758633521871089 rel dist 1 0.23855860041637142 for n_states 10
# Avg new dist 5 0.007941800308227947 rel dist 5 0.08372930978680465 for n_states 10
# Time taken: 1.8756389617919922
# dest [10.6660089   0.13952453]
# Avg new dist 1 0.2102158726413243 rel dist 1 0.6318068837585558 for n_states 10
# Avg new dist 5 0.2102158726413243 rel dist 5 0.6318068837585558 for n_states 10
# Time taken: 2.141228199005127
# dest [10.83690523  0.1373564 ]
# Avg new dist 1 0.19749697314054712 rel dist 1 0.42078801130598575 for n_states 10
# Avg new dist 5 0.19308118790732284 rel dist 5 0.41710940826737514 for n_states 10
# Time taken: 2.055574655532837
# dest [10.77485039  0.13813589]
# Avg new dist 1 0.16456935563228653 rel dist 1 0.4789085659261464 for n_states 10
# Avg new dist 5 0.16456935563228653 rel dist 5 0.4789085659261464 for n_states 10
# Time taken: 2.2126517295837402
# dest [11.02177952  0.13508511]
# Avg new dist 1 0.17122383274948066 rel dist 1 0.6026191401676864 for n_states 10
# Avg new dist 5 0.10422608845974213 rel dist 5 0.5273533935346089 for n_states 10
# Time taken: 2.3315727710723877
# dest [10.98358058  0.13554826]
# Avg new dist 1 0.12158258898189553 rel dist 1 0.5144073143784904 for n_states 10
# Avg new dist 5 0.1001771714918636 rel dist 5 0.4817490531310522 for n_states 10
# Time taken: 2.49273419380188
# dest [11.52857794  0.1292252 ]
# Avg new dist 1 0.13362683552026713 rel dist 1 0.25514013393779084 for n_states 10
# Avg new dist 5 0.11998387615998937 rel dist 5 0.226709803837187 for n_states 10
# Time taken: 2.4329633712768555
# time taken 2.0920761585235597

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Buckling')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(1)
evalObject.setNStates(500)

time_taken = 0.0
#print_dests = []
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 61

    dest = ref_traj[time_step]
    #print_dests.append(dest)
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))

# plt.figure(1)
# x_index = 0
# y_index = 1
# plt.xlabel('x' + str(x_index))
# plt.ylabel('x' + str(y_index))
# print_dests = np.array(print_dests)
# plt.plot(print_dests[:,x_index], print_dests[:, y_index], 'r^')
# plt.show()
# Out:
# dest [-6.36729735  5.05996603]
# Avg new dist 1 8.4967658115042 rel dist 1 0.5590923210204053 for n_states 500
# Avg new dist 1 8.4967658115042 rel dist 1 0.5590923210204053 for n_states 500
# Time taken: 14.152780294418335
# dest [-5.50010586 34.2317227 ]
# Avg new dist 1 10.94029435427954 rel dist 1 0.4036555640799967 for n_states 500
# Avg new dist 1 10.94029435427954 rel dist 1 0.4036555640799967 for n_states 500
# Time taken: 17.290645837783813
# dest [1.95465252 1.88695582]
# Avg new dist 1 1.1177619224425297 rel dist 1 0.13394246558988399 for n_states 500
# Avg new dist 1 1.1177619224425297 rel dist 1 0.13394246558988399 for n_states 500
# Time taken: 11.673650979995728
# dest [ -2.06025547 -12.74279529]
# Avg new dist 1 2.2516815892934647 rel dist 1 0.2605343315842298 for n_states 500
# Avg new dist 1 2.2516815892934647 rel dist 1 0.2605343315842298 for n_states 500
# Time taken: 14.164116859436035
# dest [ -0.79029142 -10.49413504]
# Avg new dist 1 2.1146518393433076 rel dist 1 0.2506435338441213 for n_states 500
# Avg new dist 1 2.1146518393433076 rel dist 1 0.2506435338441213 for n_states 500
# Time taken: 13.609081268310547
# dest [0.81181871 1.33825027]
# Avg new dist 1 1.9271432090403224 rel dist 1 0.22387974252722898 for n_states 500
# Avg new dist 1 1.9271432090403224 rel dist 1 0.22387974252722898 for n_states 500
# Time taken: 11.419596672058105
# dest [ 1.66588592 -8.74787523]
# Avg new dist 1 1.2302442127643676 rel dist 1 0.24084117041759456 for n_states 500
# Avg new dist 1 1.2302442127643676 rel dist 1 0.24084117041759456 for n_states 500
# Time taken: 13.06164026260376
# dest [1.67806951 1.20367329]
# Avg new dist 1 1.2227740146440527 rel dist 1 0.16112156462539165 for n_states 500
# Avg new dist 1 1.2227740146440527 rel dist 1 0.16112156462539165 for n_states 500
# Time taken: 12.876453876495361
# dest [-4.46257438 41.48502896]
# Avg new dist 1 12.44566136457974 rel dist 1 0.37892851379742076 for n_states 500
# Avg new dist 1 12.44566136457974 rel dist 1 0.37892851379742076 for n_states 500
# Time taken: 21.313356161117554
# dest [ -5.31511128 -11.38755182]
# Avg new dist 1 3.4751555864998824 rel dist 1 0.3823866023855832 for n_states 500
# Avg new dist 1 3.4751555864998824 rel dist 1 0.3823866023855832 for n_states 500
# Time taken: 19.444090366363525
# time taken 14.905603528022766

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lotka')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 60

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# dest [0.66311861 3.0290321 ]
# Avg new dist 1 0.32783116475337276 rel dist 1 0.30616418057734096 for n_states 500
# Avg new dist 5 0.19455363923352342 rel dist 5 0.24013733133143547 for n_states 500
# Time taken: 15.352676391601562
# dest [0.23664491 3.96887405]
# Avg new dist 1 0.2643854431469239 rel dist 1 0.19475741696196455 for n_states 500
# Avg new dist 5 0.1240476243639863 rel dist 5 0.1468770238869355 for n_states 500
# Time taken: 16.113443851470947
# dest [0.38289173 1.19983246]
# Avg new dist 1 0.40439890887096147 rel dist 1 0.25429370226437004 for n_states 500
# Avg new dist 5 0.15907379752772585 rel dist 5 0.1303120653805382 for n_states 500
# Time taken: 17.12601113319397
# dest [1.07231757 4.2802733 ]
# Avg new dist 1 0.42591371351755947 rel dist 1 0.2882776010528991 for n_states 500
# Avg new dist 5 0.27705170892199 rel dist 5 0.21533879218975702 for n_states 500
# Time taken: 16.670254945755005
# dest [3.36741624 2.18615292]
# Avg new dist 1 1.355512641271933 rel dist 1 0.4818031242433204 for n_states 500
# Avg new dist 5 0.941096250479497 rel dist 5 0.35704190664060315 for n_states 500
# Time taken: 14.979601860046387
# dest [5.17847059 4.28362241]
# Avg new dist 1 2.6873523020722594 rel dist 1 0.5732934596496476 for n_states 500
# Avg new dist 5 1.0045192454128042 rel dist 5 0.22520290027132486 for n_states 500
# Time taken: 15.507615566253662
# dest [0.53077639 2.90539838]
# Avg new dist 1 0.2899944337461786 rel dist 1 0.30990548463511797 for n_states 500
# Avg new dist 5 0.19957982190156856 rel dist 5 0.27223130114773014 for n_states 500
# Time taken: 16.942061185836792
# dest [0.3535268  2.86302406]
# Avg new dist 1 0.3194895974569488 rel dist 1 0.2896312938354147 for n_states 500
# Avg new dist 5 0.06210912363625135 rel dist 5 0.10208617689645651 for n_states 500
# Time taken: 18.518805742263794
# dest [3.48240604 1.7625394 ]
# Avg new dist 1 1.4664712978264498 rel dist 1 0.4929494537374388 for n_states 500
# Avg new dist 5 1.0267650605726728 rel dist 5 0.36723147791114863 for n_states 500
# Time taken: 16.814029932022095
# dest [0.38788535 0.72099159]
# Avg new dist 1 0.5162206868373332 rel dist 1 0.21927209762161837 for n_states 500
# Avg new dist 5 0.16481372971551 rel dist 5 0.09813413882254295 for n_states 500
# Time taken: 19.104104042053223
# time taken 16.71457917690277

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Jetengine')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(50)

time_taken = 0.0
# print_dests = []
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 31

    dest = ref_traj[time_step]
    # print_dests.append(dest)
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))

# plt.figure(1)
# x_index = 0
# y_index = 1
# plt.xlabel('x' + str(x_index))
# plt.ylabel('x' + str(y_index))
# print_dests = np.array(print_dests)
# plt.plot(print_dests[:,x_index], print_dests[:, y_index], 'r^')
# plt.show()
# Out:
# dest [-3.00701264  4.32949914]
# Avg new dist 1 0.021975984542148982 rel dist 1 0.22346677858196323 for n_states 50
# Avg new dist 5 0.015689040139046446 rel dist 5 0.18165382288470064 for n_states 50
# Time taken: 1.8954973220825195
# dest [-2.75883825  4.15265694]
# Avg new dist 1 0.04779276270460432 rel dist 1 0.3254364706950549 for n_states 50
# Avg new dist 5 0.03656960180184976 rel dist 5 0.2848948968318755 for n_states 50
# Time taken: 1.9934463500976562
# dest [-3.10070675  4.45850912]
# Avg new dist 1 0.029991669239374054 rel dist 1 0.18559986959905914 for n_states 50
# Avg new dist 5 0.017213818797076494 rel dist 5 0.14343734197211633 for n_states 50
# Time taken: 2.0043537616729736
# dest [-3.10907842  4.42378878]
# Avg new dist 1 0.021087992345554724 rel dist 1 0.1079440430653208 for n_states 50
# Avg new dist 5 0.00614346994140386 rel dist 5 0.04085349523116876 for n_states 50
# Time taken: 2.0587799549102783
# dest [-2.74292582  4.13190149]
# Avg new dist 1 0.04971556926781437 rel dist 1 0.2868125094059429 for n_states 50
# Avg new dist 5 0.03338686056120296 rel dist 5 0.23568298351745223 for n_states 50
# Time taken: 2.04291033744812
# dest [-3.12171235  4.48815487]
# Avg new dist 1 0.0377567461961362 rel dist 1 0.143802550649552 for n_states 50
# Avg new dist 5 0.01919676277079241 rel dist 5 0.10340518843047192 for n_states 50
# Time taken: 2.2618987560272217
# dest [-2.89138145  4.21648639]
# Avg new dist 1 0.03659159088512062 rel dist 1 0.25439763903301044 for n_states 50
# Avg new dist 5 0.02416990312838568 rel dist 5 0.19587753753615172 for n_states 50
# Time taken: 2.220229148864746
# dest [-2.95512473  4.31963186]
# Avg new dist 1 0.03136178992103625 rel dist 1 0.2178415084604128 for n_states 50
# Avg new dist 5 0.026337343596579955 rel dist 5 0.1918788656952189 for n_states 50
# Time taken: 2.4111266136169434
# dest [-3.12775896  4.50302617]
# Avg new dist 1 0.0381415473446621 rel dist 1 0.20485505201754417 for n_states 50
# Avg new dist 5 0.0225281275202432 rel dist 5 0.16424967647142275 for n_states 50
# Time taken: 2.2976701259613037
# dest [-2.78970989  4.13330515]
# Avg new dist 1 0.04934423772405199 rel dist 1 0.3100219663964062 for n_states 50
# Avg new dist 5 0.02561141746027476 rel dist 5 0.23342775446837039 for n_states 50
# Time taken: 2.346524715423584
# time taken 2.155665707588196

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(10)

time_taken = 0.0
#print_dests = []
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    #print_dests.append(dest)
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))

# plt.figure(1)
# x_index = 0
# y_index = 1
# plt.xlabel('x' + str(x_index))
# plt.ylabel('x' + str(y_index))
# print_dests = np.array(print_dests)
# plt.plot(print_dests[:,x_index], print_dests[:, y_index], 'r^')
# plt.show()
# Out:
# dest [ 1.89771345 -0.62713738]
# Avg new dist 1 0.10115538041260319 rel dist 1 0.1508994293710874 for n_states 10
# Avg new dist 5 0.010299987660455697 rel dist 5 0.04559028707758526 for n_states 10
# Time taken: 0.893815279006958
# dest [ 2.46483846 -0.46487978]
# Avg new dist 1 0.13490482670179565 rel dist 1 0.30882321661826406 for n_states 10
# Avg new dist 5 0.028973629292871457 rel dist 5 0.11162535403304592 for n_states 10
# Time taken: 1.0547289848327637
# dest [ 1.89956187 -0.60311304]
# Avg new dist 1 0.09963744741059932 rel dist 1 0.24272472875232715 for n_states 10
# Avg new dist 5 0.059214773968691584 rel dist 5 0.16714772292401925 for n_states 10
# Time taken: 0.970383882522583
# dest [ 1.73704968 -0.4290377 ]
# Avg new dist 1 0.09659695272542845 rel dist 1 0.21028523175239333 for n_states 10
# Avg new dist 5 0.006308270710848401 rel dist 5 0.017621348664077465 for n_states 10
# Time taken: 1.036670207977295
# dest [ 1.94594036 -0.47020927]
# Avg new dist 1 0.07089934172450998 rel dist 1 0.18197426053894986 for n_states 10
# Avg new dist 5 0.022131184379949313 rel dist 5 0.05405542948606 for n_states 10
# Time taken: 1.0731406211853027
# dest [ 2.01117321 -0.5877978 ]
# Avg new dist 1 0.06176812271409819 rel dist 1 0.16478740146460782 for n_states 10
# Avg new dist 5 0.008983293582315918 rel dist 5 0.03685153389873265 for n_states 10
# Time taken: 1.139376163482666
# dest [ 0.7308662  -0.96900244]
# Avg new dist 1 0.1461366649970528 rel dist 1 0.15673080555331015 for n_states 10
# Avg new dist 5 0.045459629408170124 rel dist 5 0.059540194355992004 for n_states 10
# Time taken: 1.2199409008026123
# dest [ 1.80525679 -0.54977827]
# Avg new dist 1 0.11654592291889283 rel dist 1 0.3992473823724693 for n_states 10
# Avg new dist 5 0.0700058958157155 rel dist 5 0.28403616810975124 for n_states 10
# Time taken: 1.2174715995788574
# dest [ 2.02496023 -0.44633675]
# Avg new dist 1 0.07740199748366686 rel dist 1 0.14530402203811324 for n_states 10
# Avg new dist 5 0.023558249348287617 rel dist 5 0.04457675413857363 for n_states 10
# Time taken: 1.240403175354004
# dest [ 1.75988002 -0.63024297]
# Avg new dist 1 0.09094395071927455 rel dist 1 0.3601827955788171 for n_states 10
# Avg new dist 5 0.05349245173514764 rel dist 5 0.28259990451553013 for n_states 10
# Time taken: 1.30967116355896
# time taken 1.1165018558502198

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lacoperon')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(50)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 151

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [ 5.99093277 27.39428719]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 0.031692555311355716 rel dist 1 0.18279822825441538 for n_states 50
# Avg new dist 5 0.01935030221217592 rel dist 5 0.12574092138566462 for n_states 50
# Time taken: 1.5638716220855713
# dest [ 5.73507494 27.1442019 ]
# Avg new dist 1 0.041014954940198384 rel dist 1 0.2110859988853776 for n_states 50
# Avg new dist 5 0.017834948473485532 rel dist 5 0.15136919001356786 for n_states 50
# Time taken: 1.501875877380371
# dest [ 5.73978126 27.0990686 ]
# Avg new dist 1 0.048899633196434304 rel dist 1 0.22426521440462047 for n_states 50
# Avg new dist 5 0.021664364155122313 rel dist 5 0.15355882051393577 for n_states 50
# Time taken: 1.4516701698303223
# dest [ 5.76316604 27.17876985]
# Avg new dist 1 0.03699617795284958 rel dist 1 0.16161032976592668 for n_states 50
# Avg new dist 5 0.022080484270185507 rel dist 5 0.13046094828948654 for n_states 50
# Time taken: 1.6022133827209473
# dest [ 5.63716209 27.11005152]
# Avg new dist 1 0.04286696883274483 rel dist 1 0.12858918681233358 for n_states 50
# Avg new dist 5 0.005468574413726395 rel dist 5 0.054562964964576605 for n_states 50
# Time taken: 1.679915189743042
# dest [ 6.17654218 27.57190087]
# Avg new dist 1 0.04448018036208973 rel dist 1 0.14718441229906132 for n_states 50
# Avg new dist 5 0.008472471236813694 rel dist 5 0.03524377539202572 for n_states 50
# Time taken: 1.696000099182129
# dest [ 5.78645264 27.18141544]
# Avg new dist 1 0.0391609745434517 rel dist 1 0.1621769219300348 for n_states 50
# Avg new dist 5 0.017544549383281306 rel dist 5 0.10504231694784187 for n_states 50
# Time taken: 1.783137559890747
# dest [ 6.63675695 27.69765141]
# Avg new dist 1 0.08644046356037183 rel dist 1 0.12276302105663861 for n_states 50
# Avg new dist 5 0.03570179188595194 rel dist 5 0.0665384060217689 for n_states 50
# Time taken: 1.740286111831665
# dest [ 5.92060054 27.35105005]
# Avg new dist 1 0.03135889469410463 rel dist 1 0.15210098532890062 for n_states 50
# Avg new dist 5 0.01654378110616461 rel dist 5 0.09850235428660797 for n_states 50
# Time taken: 1.924330234527588
# dest [ 5.77178243 27.20952983]
# Avg new dist 1 0.03185549146022178 rel dist 1 0.2029978967720746 for n_states 50
# Avg new dist 5 0.007814383472615215 rel dist 5 0.07878577326047938 for n_states 50
# Time taken: 1.8687191009521484
# time taken 1.6834482192993163

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='HybridLinearOscillator')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [ 3.78786555 -7.55603287]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# /usr/local/lib/python3.6/dist-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# Avg new dist 1 0.9297671376072126 rel dist 1 0.21084756306144084 for n_states 500
# Avg new dist 5 0.31642479972376053 rel dist 5 0.08057895896891601 for n_states 500
# Time taken: 21.727127075195312
# dest [-1.47559034 -7.65084224]
# Avg new dist 1 0.402521630775061 rel dist 1 0.16756964072044517 for n_states 500
# Avg new dist 5 0.23102230789032915 rel dist 5 0.10195172179729166 for n_states 500
# Time taken: 21.81503200531006
# dest [ 0.18875605 -3.40567286]
# Avg new dist 1 0.5253770437814186 rel dist 1 0.15277951800694395 for n_states 500
# Avg new dist 5 0.07043334400120844 rel dist 5 0.026506613083235528 for n_states 500
# Time taken: 20.642369508743286
# dest [-2.92720927 -6.20870932]
# ../NNConfiguration_setup/frechet.py:21: RuntimeWarning: overflow encountered in double_scalars
#   square = square + pt[i]*pt[i]
# Avg new dist 1 0.49976088560340837 rel dist 1 0.1534342166941806 for n_states 500
# Avg new dist 5 0.14213158409295795 rel dist 5 0.05570774397752852 for n_states 500
# Time taken: 21.73769736289978
# dest [-0.39937974 -0.90046911]
# Avg new dist 1 4.121117793971424 rel dist 1 0.8268720708734929 for n_states 500
# Avg new dist 5 2.664627964364867 rel dist 5 0.5379656031889178 for n_states 500
# Time taken: 21.815205335617065
# dest [-1.30264143 -3.86010718]
# Avg new dist 1 0.46642828171061224 rel dist 1 0.28609902326077497 for n_states 500
# Avg new dist 5 0.03053552829736626 rel dist 5 0.015213903929229613 for n_states 500
# Time taken: 22.539050102233887
# dest [-0.38070781 -6.48470867]
# Avg new dist 1 0.2809376488605047 rel dist 1 0.1289492405982682 for n_states 500
# Avg new dist 5 0.14273025927131908 rel dist 5 0.07200655838325565 for n_states 500
# Time taken: 22.932178258895874
# dest [-1.846163   -6.55502584]
# Avg new dist 1 0.3755377926044624 rel dist 1 0.2856823721530423 for n_states 500
# Avg new dist 5 0.10885776343393627 rel dist 5 0.05359218393759451 for n_states 500
# Time taken: 22.878003358840942
# dest [-0.61734023 -7.82808174]
# Avg new dist 1 0.5490119106867911 rel dist 1 0.19914317661604244 for n_states 500
# Avg new dist 5 0.223006165998775 rel dist 5 0.1038060510679337 for n_states 500
# Time taken: 22.85514760017395
# dest [-2.36329675 -6.16735057]
# Avg new dist 1 0.4504835244884522 rel dist 1 0.23624884701812765 for n_states 500
# Avg new dist 5 0.13616174564542183 rel dist 5 0.06334451372278928 for n_states 500
# Time taken: 22.78398561477661
# time taken 22.174676775932312

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SmoothHybridLinearOscillator')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [ -0.2162888  -11.15413546]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# /usr/local/lib/python3.6/dist-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# Avg new dist 1 0.5685770073378261 rel dist 1 0.18038184817518543 for n_states 500
# Avg new dist 5 0.107504748870258 rel dist 5 0.05575949644600543 for n_states 500
# Time taken: 78.17889881134033
# dest [ 0.20905216 -8.76235866]
# Avg new dist 1 0.6581445102705678 rel dist 1 0.2227448111321288 for n_states 500
# Avg new dist 5 0.12476759007110365 rel dist 5 0.05711411247055192 for n_states 500
# Time taken: 73.28591179847717
# dest [-0.50580685 -4.09958094]
# Avg new dist 1 0.388540430197493 rel dist 1 0.15896982912745072 for n_states 500
# Avg new dist 5 0.052504407164849304 rel dist 5 0.02389798962095022 for n_states 500
# Time taken: 55.888142108917236
# dest [-0.17968018 -6.92202211]
# Avg new dist 1 0.43509353584498567 rel dist 1 0.20025520561794086 for n_states 500
# Avg new dist 5 0.0811824959902396 rel dist 5 0.04555652992487315 for n_states 500
# Time taken: 68.97096014022827
# dest [ 2.36127526 -3.60106582]
# Avg new dist 1 0.919308980614619 rel dist 1 0.23836989784536317 for n_states 500
# Avg new dist 5 0.1355448567652579 rel dist 5 0.03693555039041368 for n_states 500
# Time taken: 58.00804924964905
# dest [-0.46447716 -3.91308354]
# Avg new dist 1 0.3764392021712674 rel dist 1 0.13150732118707953 for n_states 500
# Avg new dist 5 0.04600983868543801 rel dist 5 0.017207301299651197 for n_states 500
# Time taken: 55.878984451293945
# dest [-0.7547598  -7.21070966]
# Avg new dist 1 0.45645086143906893 rel dist 1 0.16668350499022272 for n_states 500
# Avg new dist 5 0.06437525756608573 rel dist 5 0.035255348210648164 for n_states 500
# Time taken: 71.47401690483093
# dest [ -0.72075163 -11.78150666]
# Avg new dist 1 1.0983539721458135 rel dist 1 0.3649344943949661 for n_states 500
# Avg new dist 5 0.423806151777947 rel dist 5 0.18286978237380377 for n_states 500
# Time taken: 79.513756275177
# dest [  0.90812847 -10.50483142]
# Avg new dist 1 0.6291120899377441 rel dist 1 0.2285220404356533 for n_states 500
# Avg new dist 5 0.16290246539546463 rel dist 5 0.05837680448314291 for n_states 500
# Time taken: 79.64709281921387
# dest [-0.34041009 -4.44375335]
# Avg new dist 1 0.3845239405653099 rel dist 1 0.169960314646391 for n_states 500
# Avg new dist 5 0.08338302531880805 rel dist 5 0.034107634957980214 for n_states 500
# Time taken: 60.29998970031738
# time taken 68.1228402376175

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Roesseler')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# dest [-6.66663938 -3.58896119  0.01587209]
# Avg new dist 1 0.8447661737430253 rel dist 1 0.27960670197412213 for n_states 500
# Avg new dist 5 0.36426891133061623 rel dist 5 0.1414679087617471 for n_states 500
# Time taken: 20.56654930114746
# dest [-6.12948578 -8.3374419   0.01609638]
# Avg new dist 1 1.4828906374449882 rel dist 1 0.27458354843448085 for n_states 500
# Avg new dist 5 0.2752060950979699 rel dist 5 0.06577707355418883 for n_states 500
# Time taken: 21.158403873443604
# dest [-3.84065274 -8.71535269  0.01944041]
# Avg new dist 1 2.0271871149755247 rel dist 1 0.3456527762512877 for n_states 500
# Avg new dist 5 0.634217515612836 rel dist 5 0.12166570219292 for n_states 500
# Time taken: 21.64684247970581
# dest [-9.22674246 -7.26690142  0.01303349]
# Avg new dist 1 1.0902193950547936 rel dist 1 0.258862028400798 for n_states 500
# Avg new dist 5 0.33948196506200884 rel dist 5 0.09805494057114864 for n_states 500
# Time taken: 22.81493306159973
# dest [-9.4476007  -6.61842622  0.01288535]
# Avg new dist 1 0.9756208367958489 rel dist 1 0.2478605539559769 for n_states 500
# Avg new dist 5 0.3853194006889272 rel dist 5 0.11801135376542603 for n_states 500
# Time taken: 23.1382839679718
# dest [-1.10054765 -4.17236496  0.02739677]
# Avg new dist 1 1.917324895930408 rel dist 1 0.3485063920915159 for n_states 500
# Avg new dist 5 1.0136247704048134 rel dist 5 0.1923615609992163 for n_states 500
# Time taken: 19.81164002418518
# dest [-6.48950321 -2.41470604  0.01621107]
# Avg new dist 1 0.7274593154481598 rel dist 1 0.2953658172499814 for n_states 500
# Avg new dist 5 0.21157181662203006 rel dist 5 0.08633974463074776 for n_states 500
# Time taken: 21.572365283966064
# dest [-6.61517644 -8.6916895   0.01548701]
# Avg new dist 1 1.440452682701346 rel dist 1 0.2807439895942843 for n_states 500
# Avg new dist 5 0.2890240227399464 rel dist 5 0.07605369342981126 for n_states 500
# Time taken: 24.47655153274536
# dest [-8.02882002 -7.85458656  0.01406561]
# Avg new dist 1 1.222141564288802 rel dist 1 0.26659561403031484 for n_states 500
# Avg new dist 5 0.246855660621046 rel dist 5 0.06788043343428425 for n_states 500
# Time taken: 25.23747992515564
# dest [-8.99488232  0.32506681  0.01367087]
# Avg new dist 1 1.0574600884855327 rel dist 1 0.20106970690433032 for n_states 500
# Avg new dist 5 0.3612066508587215 rel dist 5 0.08761862077600613 for n_states 500
# Time taken: 24.118939638137817
# time taken 22.45650248527527

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lorentz')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# dest [-6.56494412 -8.63168733 21.11890631]
# Avg new dist 1 1.4001991790688013 rel dist 1 0.31843176601724044 for n_states 500
# Avg new dist 5 0.47657848954804977 rel dist 5 0.132838950351514 for n_states 500
# Time taken: 34.76543164253235
# dest [ -9.10394328 -10.42490445  25.98890757]
# Avg new dist 1 0.869657770326078 rel dist 1 0.27541683837772063 for n_states 500
# Avg new dist 5 0.31599696023530827 rel dist 5 0.13963987739864187 for n_states 500
# Time taken: 33.26666569709778
# dest [ -7.9674778  -11.90804839  19.63220407]
# Avg new dist 1 2.4012441206693453 rel dist 1 0.42393058633228353 for n_states 500
# Avg new dist 5 0.9680312797290943 rel dist 5 0.20913549132174247 for n_states 500
# Time taken: 37.953930377960205
# dest [ -9.6578984  -10.48023033  27.41611016]
# Avg new dist 1 1.6790222837625124 rel dist 1 0.3504129337826837 for n_states 500
# Avg new dist 5 0.9284280776052782 rel dist 5 0.2525740084278806 for n_states 500
# Time taken: 32.087164640426636
# dest [-9.13319984 -9.44937809 27.39520026]
# Avg new dist 1 1.5598991019149002 rel dist 1 0.330904797974341 for n_states 500
# Avg new dist 5 0.6618883529898971 rel dist 5 0.21101457779920754 for n_states 500
# Time taken: 31.619625329971313
# dest [-6.83675673 -8.31306893 22.63445363]
# Avg new dist 1 1.3770717602753764 rel dist 1 0.32843662063236473 for n_states 500
# Avg new dist 5 0.8377236704116657 rel dist 5 0.2128373313964975 for n_states 500
# Time taken: 34.86359119415283
# dest [ -8.16820036 -10.01366396  23.89008624]
# Avg new dist 1 1.1217278728611084 rel dist 1 0.3139509331589982 for n_states 500
# Avg new dist 5 0.4849152659630453 rel dist 5 0.17456057720654575 for n_states 500
# Time taken: 33.96326780319214
# dest [-7.9991555  -9.66764612 23.93735068]
# Avg new dist 1 1.0901085274376734 rel dist 1 0.28059270218437865 for n_states 500
# Avg new dist 5 0.3056353413529326 rel dist 5 0.10568958013660584 for n_states 500
# Time taken: 34.55447816848755
# dest [ -8.76189404 -10.08018753  25.52710072]
# Avg new dist 1 0.8855201589747884 rel dist 1 0.26106593415193147 for n_states 500
# Avg new dist 5 0.2999151384510014 rel dist 5 0.14232071469663013 for n_states 500
# Time taken: 33.63695526123047
# dest [ -8.84130363 -11.77037792  23.09419736]
# Avg new dist 1 1.4850973238174165 rel dist 1 0.3481101792705943 for n_states 500
# Avg new dist 5 0.4825059955834676 rel dist 5 0.15287147519152885 for n_states 500
# Time taken: 39.06298828125
# time taken 34.584419631958006

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Steam')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [8.19374613 6.02526803 5.25726424]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 3.608607137089145 rel dist 1 0.6040836470629567 for n_states 500
# Avg new dist 5 0.8711770449245374 rel dist 5 0.13803466384720953 for n_states 500
# Time taken: 40.28393030166626
# dest [14.31579653  9.46566497  6.25737968]
# Avg new dist 1 5.215633060288796 rel dist 1 0.6682293843137831 for n_states 500
# Avg new dist 5 0.7059584557703255 rel dist 5 0.0993446744944176 for n_states 500
# Time taken: 49.26074528694153
# dest [8.78264844 1.09003027 7.80637497]
# Avg new dist 1 4.008075838051379 rel dist 1 0.5816904802855751 for n_states 500
# Avg new dist 5 2.3132410793886597 rel dist 5 0.3228970607906466 for n_states 500
# Time taken: 48.35485649108887
# dest [12.36239549  5.78051837  2.32141247]
# Avg new dist 1 1.598384985455047 rel dist 1 0.3201112679469975 for n_states 500
# Avg new dist 5 1.0941892522271432 rel dist 5 0.22589124751733305 for n_states 500
# Time taken: 32.51065373420715
# dest [20.19098253  9.01573808  1.85265603]
# Avg new dist 1 3.0621409866274765 rel dist 1 0.3262740133790394 for n_states 500
# Avg new dist 5 1.8016968619452185 rel dist 5 0.23303600782217815 for n_states 500
# Time taken: 41.9194438457489
# dest [12.20268283  8.23315859  7.03063605]
# Avg new dist 1 3.0988145464221026 rel dist 1 1.0114829255748308 for n_states 500
# Avg new dist 5 1.791152103132417 rel dist 5 0.2960662977475066 for n_states 500
# Time taken: 51.779364347457886
# dest [6.43411586 4.07672338 4.44554541]
# Avg new dist 1 4.022433835634186 rel dist 1 0.8081506676597187 for n_states 500
# Avg new dist 5 1.837281126702492 rel dist 5 0.3087027116795178 for n_states 500
# Time taken: 40.41611957550049
# dest [10.2997753   2.72050221  2.29715958]
# Avg new dist 1 2.1200951333251346 rel dist 1 0.3117123834940916 for n_states 500
# Avg new dist 5 0.7048440586480581 rel dist 5 0.12159895460833291 for n_states 500
# Time taken: 31.067322254180908
# dest [4.63069462 2.53633379 3.65519412]
# Avg new dist 1 4.133768058858791 rel dist 1 0.6765227823422421 for n_states 500
# Avg new dist 5 2.32710673091606 rel dist 5 0.3683697272388613 for n_states 500
# Time taken: 34.926941871643066
# dest [15.531559    6.96362128  3.73633208]
# Avg new dist 1 2.4097841675933416 rel dist 1 0.36577297013601023 for n_states 500
# Avg new dist 5 0.4180637258436177 rel dist 5 0.08081477623545782 for n_states 500
# Time taken: 46.56875205039978
# time taken 41.7138484954834

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Rober')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [2.31043373e+00 1.16701941e-06 7.91559167e+00]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 1.0771629000550558 rel dist 1 0.2688456790937576 for n_states 500
# Avg new dist 5 0.30650696941791394 rel dist 5 0.09037534137811419 for n_states 500
# Time taken: 22.48544692993164
# dest [5.38483099e+00 1.52403907e-06 1.41284803e+01]
# Avg new dist 1 1.426153248752694 rel dist 1 0.2948125586768673 for n_states 500
# Avg new dist 5 0.7837702820629527 rel dist 5 0.18622834066990068 for n_states 500
# Time taken: 22.26456356048584
# dest [3.72284694e+00 1.89870117e-06 7.83723781e+00]
# Avg new dist 1 1.0262968745620078 rel dist 1 0.23083943365596338 for n_states 500
# Avg new dist 5 0.3337169913695515 rel dist 5 0.09677706077602506 for n_states 500
# Time taken: 21.960676670074463
# dest [2.12547722e+00 6.43429007e-07 1.32115071e+01]
# Avg new dist 1 1.716446821705007 rel dist 1 0.3544169525376696 for n_states 500
# Avg new dist 5 0.2825015641277718 rel dist 5 0.07069677268721676 for n_states 500
# Time taken: 23.26844882965088
# dest [7.00930839e+00 3.21536259e-06 8.71012744e+00]
# Avg new dist 1 1.08386828740184 rel dist 1 0.3365533113215718 for n_states 500
# Avg new dist 5 0.4413607217097395 rel dist 5 0.13847729857064262 for n_states 500
# Time taken: 22.417389392852783
# dest [9.29494005e+00 2.86187619e-06 1.29828080e+01]
# Avg new dist 1 1.6279524018178295 rel dist 1 0.317886002781206 for n_states 500
# Avg new dist 5 0.5776980261249853 rel dist 5 0.1418492016113938 for n_states 500
# Time taken: 22.54713487625122
# dest [8.73226747e+00 3.11364793e-06 1.12087128e+01]
# Avg new dist 1 1.0878114437626678 rel dist 1 0.25212490633559115 for n_states 500
# Avg new dist 5 0.2931357340373485 rel dist 5 0.08391018364307544 for n_states 500
# Time taken: 23.257081508636475
# dest [8.02457415e+00 5.31723360e-06 6.02070178e+00]
# Avg new dist 1 1.2289584296494322 rel dist 1 0.20267925542098633 for n_states 500
# Avg new dist 5 0.2557536996489734 rel dist 5 0.06031124710525505 for n_states 500
# Time taken: 23.353824853897095
# dest [3.60135776e+00 8.52903279e-07 1.68873178e+01]
# Avg new dist 1 1.5507112775309833 rel dist 1 0.2600061626965634 for n_states 500
# Avg new dist 5 0.7814795921941532 rel dist 5 0.1398108737548185 for n_states 500
# Time taken: 24.701300144195557
# dest [4.81301832e+00 2.00991644e-06 9.57251438e+00]
# Avg new dist 1 0.9722753883314996 rel dist 1 0.26878482270679876 for n_states 500
# Avg new dist 5 0.22016362982711224 rel dist 5 0.07762811193817866 for n_states 500
# Time taken: 24.877007722854614
# time taken 23.115458703041078

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='CoupledVanderpol')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# dest [ 6.39396967 -0.24628271  2.96050937  0.08024422]
# Avg new dist 1 1.098936016450369 rel dist 1 0.38870780094840246 for n_states 500
# Avg new dist 5 0.2380106459413361 rel dist 5 0.09314260719074535 for n_states 500
# Time taken: 50.46949529647827
# dest [ 8.69427083 -0.13902428  7.01641303 -0.11065095]
# Avg new dist 1 1.7241667269455072 rel dist 1 0.5000978372547924 for n_states 500
# Avg new dist 5 0.48987244658501183 rel dist 5 0.16918469406158074 for n_states 500
# Time taken: 35.95145320892334
# dest [ 2.93773181 -0.42425358  2.56473736 -0.38085357]
# Avg new dist 1 0.9959778661117757 rel dist 1 0.532636740432014 for n_states 500
# Avg new dist 5 0.2874179048209628 rel dist 5 0.15214595293388866 for n_states 500
# Time taken: 50.1890652179718
# dest [ 3.84709354 -0.34707381  2.86979696 -0.25745497]
# Avg new dist 1 1.094072851518052 rel dist 1 0.5993722724172461 for n_states 500
# Avg new dist 5 0.32393701871243913 rel dist 5 0.15991577414242503 for n_states 500
# Time taken: 52.23095178604126
# dest [ 5.86011233 -0.10753073  8.13265204 -0.15968798]
# Avg new dist 1 1.5051083997281756 rel dist 1 0.5319139602513502 for n_states 500
# Avg new dist 5 0.21365355041793682 rel dist 5 0.07606702777702089 for n_states 500
# Time taken: 40.063974142074585
# dest [ 3.28113086 -0.15220146  5.06130912 -0.27730309]
# Avg new dist 1 1.426288668086845 rel dist 1 0.6602028075780179 for n_states 500
# Avg new dist 5 0.4213542271076961 rel dist 5 0.20364268423454818 for n_states 500
# Time taken: 49.507487297058105
# dest [ 2.41879536 -0.42231554  2.69783425 -0.45924673]
# Avg new dist 1 0.8771277607520979 rel dist 1 0.3527218353691771 for n_states 500
# Avg new dist 5 0.33788184035528446 rel dist 5 0.18100066778554452 for n_states 500
# Time taken: 50.390103816986084
# dest [ 6.12549584 -0.25721391  2.85101512  0.07104586]
# Avg new dist 1 0.9541945249595714 rel dist 1 0.3438945150684594 for n_states 500
# Avg new dist 5 0.20098778689458047 rel dist 5 0.0858662256627424 for n_states 500
# Time taken: 56.040719509124756
# dest [ 4.82405966 -0.19387362  5.32188078 -0.2126678 ]
# Avg new dist 1 1.2572123800623614 rel dist 1 0.5003044681579201 for n_states 500
# Avg new dist 5 0.4079533248101806 rel dist 5 0.17926794456046663 for n_states 500
# Time taken: 52.05777192115784
# dest [ 4.38278237 -0.30687317  3.15474748 -0.2131053 ]
# Avg new dist 1 1.1654592092122964 rel dist 1 0.5762277602064776 for n_states 500
# Avg new dist 5 0.3217945885654695 rel dist 5 0.1466459689310875 for n_states 500
# Time taken: 58.75404119491577
# time taken 49.56830835342407

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='LaubLoomis')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [0.88819769 0.44353056 0.52138348 2.67456272 0.24617048 0.08817587
#  0.25189351]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 0.004365099252702517 rel dist 1 0.4144636272349531 for n_states 500
# Avg new dist 5 0.003786559477060767 rel dist 5 0.3113271961172656 for n_states 500
# Time taken: 22.4240460395813
# dest [0.89390757 0.45177255 0.52117167 2.65861135 0.250187   0.08888285
#  0.25110815]
# Avg new dist 1 0.004172082462152038 rel dist 1 0.29731766878286403 for n_states 500
# Avg new dist 5 0.003337696357014751 rel dist 5 0.2417637812012851 for n_states 500
# Time taken: 22.416988372802734
# dest [0.88639181 0.44561815 0.51804861 2.67886172 0.24602445 0.08811232
#  0.25042084]
# Avg new dist 1 0.003428187948960962 rel dist 1 0.3535019319895238 for n_states 500
# Avg new dist 5 0.0030885184048449884 rel dist 5 0.261910245033869 for n_states 500
# Time taken: 22.369045972824097
# dest [0.8879811  0.43357801 0.52842672 2.67719441 0.24368971 0.08781889
#  0.2555204 ]
# Avg new dist 1 0.007915472163075473 rel dist 1 0.3887020553620211 for n_states 500
# Avg new dist 5 0.003251453531175648 rel dist 5 0.1751906140485735 for n_states 500
# Time taken: 25.285890340805054
# dest [0.89530206 0.45002735 0.52383799 2.6553226  0.25026829 0.08892762
#  0.2522897 ]
# Avg new dist 1 0.007693816620322407 rel dist 1 0.5120951163808793 for n_states 500
# Avg new dist 5 0.006148469989803331 rel dist 5 0.40968219069866013 for n_states 500
# Time taken: 24.918098211288452
# dest [0.89209407 0.44569772 0.52374134 2.66421072 0.2480788  0.08854067
#  0.25262339]
# Avg new dist 1 0.00504743260254575 rel dist 1 0.46441858790771157 for n_states 500
# Avg new dist 5 0.004304702305300071 rel dist 5 0.3660432448987364 for n_states 500
# Time taken: 24.644747495651245
# dest [0.89577206 0.44417888 0.52855922 2.65516178 0.24901861 0.08876335
#  0.25463494]
# Avg new dist 1 0.005910213571887727 rel dist 1 0.39774878262601465 for n_states 500
# Avg new dist 5 0.003712446708364716 rel dist 5 0.2884923145130834 for n_states 500
# Time taken: 25.273826599121094
# dest [0.8866966  0.44878481 0.51606903 2.67758675 0.24688457 0.08824285
#  0.24938895]
# Avg new dist 1 0.0034985042399420935 rel dist 1 0.21635748391339382 for n_states 500
# Avg new dist 5 0.001703503206135302 rel dist 5 0.11113149381308066 for n_states 500
# Time taken: 24.274041414260864
# dest [0.88690567 0.44196193 0.52121833 2.67816848 0.24533536 0.08802588
#  0.25196423]
# Avg new dist 1 0.004053237259676211 rel dist 1 0.37003577919519476 for n_states 500
# Avg new dist 5 0.003751372414931846 rel dist 5 0.30538710021505544 for n_states 500
# Time taken: 24.02048373222351
# dest [0.8877344  0.43551646 0.52675673 2.67737265 0.24407422 0.08786703
#  0.25469275]
# Avg new dist 1 0.006049384137791318 rel dist 1 0.3794312437253121 for n_states 500
# Avg new dist 5 0.00480113610861251 rel dist 5 0.29042045559556906 for n_states 500
# Time taken: 24.25968837738037
# time taken 23.991088819503783

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='MC')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 81

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [0.0445832  0.04521245]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 0.001013313692287473 rel dist 1 0.08010250284559658 for n_states 500
# Avg new dist 5 0.0005198775018758086 rel dist 5 0.07605736651547956 for n_states 500
# Time taken: 97.83046340942383
# dest [0.03882626 0.04650718]
# Avg new dist 1 0.0014217670100639458 rel dist 1 0.11237387456440825 for n_states 500
# Avg new dist 5 0.0004108148985093897 rel dist 5 0.05289011290648034 for n_states 500
# Time taken: 105.99920558929443
# dest [-0.00799748  0.05108905]
# Avg new dist 1 0.01048532978145278 rel dist 1 0.22381433729722405 for n_states 500
# Avg new dist 5 0.0026607590860531433 rel dist 5 0.10540720065682672 for n_states 500
# Time taken: 185.5144383907318
# dest [0.03798515 0.04665067]
# Avg new dist 1 0.0014940353170580039 rel dist 1 0.09950297053009925 for n_states 500
# Avg new dist 5 0.00034967706954138546 rel dist 5 0.03567371100942361 for n_states 500
# Time taken: 104.37163639068604
# dest [-0.10332393  0.05582334]
# Avg new dist 1 0.005331144816607352 rel dist 1 0.14923402624361848 for n_states 500
# Avg new dist 5 0.004139287309764778 rel dist 5 0.08776849705040614 for n_states 500
# Time taken: 186.94622588157654
# dest [-0.01554183  0.05158303]
# Avg new dist 1 0.01128173109423508 rel dist 1 0.18541856142572233 for n_states 500
# Avg new dist 5 0.0031004502245084585 rel dist 5 0.09781487716527454 for n_states 500
# Time taken: 181.0214946269989
# dest [-0.43923577  0.06030733]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-66723e8d2138> in <module>
#      19     dest = ref_traj[time_step]
#      20     dests = [dest]
# ---> 21     evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
#      22     time_taken += time.time() - start
#      23 print("time taken {}".format(time_taken/10))
#
# ~/Research/cps-falsification/pyExploreNN/L4DC/evaluation.py in reachDest(self, src, dests, d_time_steps, threshold, eval_first_step)
#     384                     # self.data_object.showTrajectories(ref_traj)
#     385
# --> 386                     curr_iter_states, curr_state, curr_dist = self.reachDest_wo_f(curr_ref_traj, dest, d_time_step, threshold, model_v)
#     387                     if curr_dist < dist:
#     388                         dist = curr_dist
#
# ~/Research/cps-falsification/pyExploreNN/L4DC/evaluation.py in reachDest_wo_f(self, ref_traj, dest, d_time_step, threshold, model_v)
#     141             # if data_object.dynamics == 'MC':
#     142             #     new_init_state[0][1:] = 0.0
# --> 143             new_traj = self.data_object.generateTrajectories(r_states=new_init_state)[0]
#     144             x_val = new_traj[0]
#     145
#
# ~/Research/cps-falsification/pyExploreNN/NNConfiguration_setup/configuration.py in generateTrajectories(self, samples, r_states)
#      55             plant = Plant('MC', dnn_controller_obj, None, self.steps)
#      56             if r_states is not None:
# ---> 57                 trajectories = plant.getSimulations(states=r_states)
#      58                 return trajectories
#      59             else:
#
# ~/Research/cps-falsification/pyExploreNN/NNConfiguration_setup/verisigSystems.py in getSimulations(self, states)
#     406     def getSimulations(self, states):
#     407         if self.dnn_controller is not None:
# --> 408             self.dnn_controller.parseDNNYML(self.model)
#     409         if self.model is 'ABS':
#     410             self.dnn_transform.parseDNNYML(self.model)
#
# ~/Research/cps-falsification/pyExploreNN/NNConfiguration_setup/verisigSystems.py in parseDNNYML(self, dynamics)
#      19         # print("Parsing DNN YML file.")
#      20         yaml_f = open(self.dnn_file, 'r')
# ---> 21         yml_obj = yaml.load(yaml_f)
#      22         acts = yml_obj.get('activations')
#      23         offsets = yml_obj.get('offsets')
#
# /usr/lib/python3/dist-packages/yaml/__init__.py in load(stream, Loader)
#      70     loader = Loader(stream)
#      71     try:
# ---> 72         return loader.get_single_data()
#      73     finally:
#      74         loader.dispose()
#
# /usr/lib/python3/dist-packages/yaml/constructor.py in get_single_data(self)
#      33     def get_single_data(self):
#      34         # Ensure that the stream contains a single document and construct it.
# ---> 35         node = self.get_single_node()
#      36         if node is not None:
#      37             return self.construct_document(node)
#
# /usr/lib/python3/dist-packages/yaml/composer.py in get_single_node(self)
#      34         document = None
#      35         if not self.check_event(StreamEndEvent):
# ---> 36             document = self.compose_document()
#      37
#      38         # Ensure that the stream contains no more documents.
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_document(self)
#      53
#      54         # Compose the root node.
# ---> 55         node = self.compose_node(None, None)
#      56
#      57         # Drop the DOCUMENT-END event.
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      80             node = self.compose_scalar_node(anchor)
#      81         elif self.check_event(SequenceStartEvent):
# ---> 82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
#      84             node = self.compose_mapping_node(anchor)
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_sequence_node(self, anchor)
#     109         index = 0
#     110         while not self.check_event(SequenceEndEvent):
# --> 111             node.value.append(self.compose_node(node, index))
#     112             index += 1
#     113         end_event = self.get_event()
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      80             node = self.compose_scalar_node(anchor)
#      81         elif self.check_event(SequenceStartEvent):
# ---> 82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
#      84             node = self.compose_mapping_node(anchor)
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_sequence_node(self, anchor)
#     108             self.anchors[anchor] = node
#     109         index = 0
# --> 110         while not self.check_event(SequenceEndEvent):
#     111             node.value.append(self.compose_node(node, index))
#     112             index += 1
#
# /usr/lib/python3/dist-packages/yaml/parser.py in check_event(self, *choices)
#      96         if self.current_event is None:
#      97             if self.state:
# ---> 98                 self.current_event = self.state()
#      99         if self.current_event is not None:
#     100             if not choices:
#
# /usr/lib/python3/dist-packages/yaml/parser.py in parse_block_sequence_entry(self)
#     382         if self.check_token(BlockEntryToken):
#     383             token = self.get_token()
# --> 384             if not self.check_token(BlockEntryToken, BlockEndToken):
#     385                 self.states.append(self.parse_block_sequence_entry)
#     386                 return self.parse_block_node()
#
# /usr/lib/python3/dist-packages/yaml/scanner.py in check_token(self, *choices)
#     114         # Check if the next token is one of the given types.
#     115         while self.need_more_tokens():
# --> 116             self.fetch_more_tokens()
#     117         if self.tokens:
#     118             if not choices:
#
# /usr/lib/python3/dist-packages/yaml/scanner.py in fetch_more_tokens(self)
#     250         # It must be a plain scalar then.
#     251         if self.check_plain():
# --> 252             return self.fetch_plain()
#     253
#     254         # No? It's an error. Let's produce a nice error message.
#
# /usr/lib/python3/dist-packages/yaml/scanner.py in fetch_plain(self)
#     674
#     675         # Scan and add SCALAR. May change `allow_simple_key`.
# --> 676         self.tokens.append(self.scan_plain())
#     677
#     678     # Checkers.
#
# /usr/lib/python3/dist-packages/yaml/scanner.py in scan_plain(self)
#    1284                 break
#    1285             while True:
# -> 1286                 ch = self.peek(length)
#    1287                 if ch in '\0 \t\r\n\x85\u2028\u2029'    \
#    1288                         or (not self.flow_level and ch == ':' and
#
# /usr/lib/python3/dist-packages/yaml/reader.py in peek(self, index)
#      85             self.determine_encoding()
#      86
# ---> 87     def peek(self, index=0):
#      88         try:
#      89             return self.buffer[self.pointer+index]
#
# KeyboardInterrupt:

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Quadrotor')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 81

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [ 0.05038302  0.13459182  0.648       0.79726934 -0.79726934  1.62      ]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 0.014459465904538449 rel dist 1 0.19166388368996376 for n_states 500
# Avg new dist 5 0.010733424224002072 rel dist 5 0.13183085779463252 for n_states 500
# Time taken: 354.28575229644775
# dest [-0.13025379 -0.14007522  0.648       0.63978404 -0.32481343  1.62      ]
# Avg new dist 1 0.051758577501685846 rel dist 1 0.12123904497982045 for n_states 500
# Avg new dist 5 0.009950239553901091 rel dist 5 0.03198509089619415 for n_states 500
# Time taken: 349.9868321418762
# dest [-0.22420005  0.06243252  0.648       0.56104139 -0.10827114  1.62      ]
# Avg new dist 1 0.016874793004185967 rel dist 1 0.13526265342807742 for n_states 500
# Avg new dist 5 0.013348178361577293 rel dist 5 0.06833100603166442 for n_states 500
# Time taken: 350.88051295280457
# dest [ 0.26392662 -0.3518163  -0.4368      0.79726934 -0.79726934 -0.3       ]
# Avg new dist 1 0.9930271116128858 rel dist 1 2.4080589579896925 for n_states 500
# Avg new dist 5 0.04131807990640972 rel dist 5 0.06031399835980692 for n_states 500
# Time taken: 347.05191373825073
# dest [ 0.07389963  0.24671642 -0.6168      0.79726934 -0.79726934 -1.1       ]
# Avg new dist 1 0.0342606631961314 rel dist 1 0.11651182045470453 for n_states 500
# Avg new dist 5 0.02094551950629976 rel dist 5 0.07079573770498078 for n_states 500
# Time taken: 345.6097798347473
# dest [ 0.28473266 -0.35642817 -0.4368      0.79726934 -0.79726934 -0.3       ]
# Avg new dist 1 1.088685714409743 rel dist 1 1.673912281834121 for n_states 500
# Avg new dist 5 0.029112516852021323 rel dist 5 0.03331787212023303 for n_states 500
# Time taken: 361.9730648994446
# dest [-0.17166394 -0.09219065  0.648       0.62009837 -0.28544211  1.62      ]
# Avg new dist 1 0.03196817295019519 rel dist 1 0.13131168527316558 for n_states 500
# Avg new dist 5 0.010392332151888856 rel dist 5 0.0530472817057418 for n_states 500
# Time taken: 351.2996258735657
# dest [-0.2148314  -0.06537388  0.648       0.62009837 -0.20669946  1.62      ]
# Avg new dist 1 0.027021817439966976 rel dist 1 0.06655119576513233 for n_states 500
# Avg new dist 5 0.006417502325282217 rel dist 5 0.029625839407313864 for n_states 500
# Time taken: 365.4090266227722
# dest [-0.19556014 -0.03857926  0.648       0.60041271 -0.22638512  1.62      ]
# Avg new dist 1 0.027472831370531914 rel dist 1 0.13406524628750052 for n_states 500
# Avg new dist 5 0.014452000809269724 rel dist 5 0.08742181863985876 for n_states 500
# Time taken: 355.9529004096985
# dest [ 0.04948902  0.22007548 -0.6116      0.79726934 -0.79726934 -1.06      ]
# Avg new dist 1 0.023150053005311425 rel dist 1 0.060127888505035386 for n_states 500
# Avg new dist 5 0.004609751473189358 rel dist 5 0.02180698313540963 for n_states 500
# Time taken: 344.5635783672333
# time taken 352.74865026474

# %%
import matplotlib
# %matplotlib inline
import numpy as np

from evaluation import Evaluation

evalObject = Evaluation(dynamics='BiologicalModel1')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(10)
evalObject.setNStates(5)

ref_traj = dataObject.generateTrajectories(samples=1)
ref_traj = ref_traj[0]
time_step = 71

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.1)
# Out:
# dest [3.98422352 1.5831738  0.17542259 1.8035239  0.06891382 4.59415257
#  3.38501988]
# pred init state [1.70126563 3.1981959  0.50515861 1.212077   0.98165357 5.099999
#  3.4516082 ], pred dest state [3.74872285 1.51372063 0.14217666 2.13198058 0.06174999 4.92336194
#  3.62824527] distance 0.5803982292148371
# pred init state [1.53254895 3.44248284 0.73541097 1.40463041 0.53427586 5.099999
#  3.18636029], pred dest state [3.94608289 1.59358249 0.17077739 1.86907373 0.06983253 4.58449838
#  3.70186091] distance 0.32613446938241775
# pred init state [1.22547304 3.02168112 1.04723627 1.08039631 0.83072682 5.099999
#  2.83700519], pred dest state [3.65843531 1.47569856 0.16025657 1.84423181 0.06689132 4.43300969
#  3.5039945 ] distance 0.39962745793411675
# pred init state [1.85550417 3.34419158 0.34892926 1.53072006 0.5674283  5.099999
#  3.48818638], pred dest state [3.84337286 1.55250519 0.15274697 2.03547701 0.06267135 4.97367317
#  3.61451222] distance 0.5213803641001051
# pred init state [1.46586411 3.38285826 0.2083112  1.12170492 1.0944772  4.94792855
#  3.16212186], pred dest state [3.50594694 1.41918408 0.13190254 2.1550864  0.06109572 4.66860422
#  3.4414462 ] distance 0.6244352653381189
# Avg Relative distance 0.09471385069410006 for n_states 5

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='VehiclePlatoon')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(500)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 131

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [ 1.28351818 -0.24315102  0.30254021  1.32040939 -0.36801123  0.09281435
#   0.99650411 -0.64947866 -0.02573794]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 0.017533954690278204 rel dist 1 0.23915544577468717 for n_states 500
# Avg new dist 5 0.01231755995108371 rel dist 5 0.18040959974922688 for n_states 500
# Time taken: 20.80425214767456
# dest [ 1.34244863 -0.26332225  0.30572155  1.33713673 -0.37668436  0.08761979
#   0.99292841 -0.63958615 -0.03258548]
# Avg new dist 1 0.023180611072216157 rel dist 1 0.22652297607458538 for n_states 500
# Avg new dist 5 0.010460952262659999 rel dist 5 0.11463162493933095 for n_states 500
# Time taken: 20.935596466064453
# dest [ 1.33331965 -0.26958015  0.2905644   1.32821699 -0.37418446  0.09318544
#   0.97296919 -0.60642275 -0.01767544]
# Avg new dist 1 0.027467624556699887 rel dist 1 0.2361280919157901 for n_states 500
# Avg new dist 5 0.021127740106900314 rel dist 5 0.19618520245306106 for n_states 500
# Time taken: 20.81174325942993
# dest [ 1.23666996 -0.21318915  0.32250061  1.3363615  -0.36153878  0.10420385
#   1.05028379 -0.712807   -0.01993162]
# Avg new dist 1 0.02764149471473556 rel dist 1 0.27324586180493515 for n_states 500
# Avg new dist 5 0.014731900840798373 rel dist 5 0.1553178473705936 for n_states 500
# Time taken: 21.23013949394226
# dest [ 1.26292097 -0.22372122  0.3192375   1.35481868 -0.40323776  0.06515708
#   0.97683728 -0.62083814 -0.01476254]
# Avg new dist 1 0.017433089163907005 rel dist 1 0.18722736384248678 for n_states 500
# Avg new dist 5 0.008279306167154388 rel dist 5 0.0961741443355292 for n_states 500
# Time taken: 21.295544147491455
# dest [ 1.29704121 -0.24034415  0.31680278  1.32145546 -0.37842007  0.07516231
#   0.98846643 -0.64859183 -0.03506767]
# Avg new dist 1 0.02021310649174978 rel dist 1 0.2381897822600377 for n_states 500
# Avg new dist 5 0.0118333217363922 rel dist 5 0.16140170562413744 for n_states 500
# Time taken: 21.730858325958252
# dest [ 1.23288381 -0.21883637  0.30966547  1.32315439 -0.39467843  0.06281282
#   0.94688128 -0.60590248 -0.02084373]
# Avg new dist 1 0.023319947006426103 rel dist 1 0.22031099965706077 for n_states 500
# Avg new dist 5 0.014145830805742887 rel dist 5 0.15077698502397208 for n_states 500
# Time taken: 22.111445903778076
# dest [ 1.29928063 -0.24590306  0.30628326  1.32433704 -0.35771836  0.10102839
#   1.07191494 -0.69787568 -0.01911971]
# Avg new dist 1 0.03488488909365689 rel dist 1 0.34428913942283773 for n_states 500
# Avg new dist 5 0.017898545724661454 rel dist 5 0.19601607239264018 for n_states 500
# Time taken: 21.87464714050293
# dest [ 1.21818081 -0.21679782  0.30948784  1.27377836 -0.38155253  0.05276262
#   0.91738196 -0.59396201 -0.03030642]
# Avg new dist 1 0.03893995076945263 rel dist 1 0.3186101267660265 for n_states 500
# Avg new dist 5 0.024017292462151025 rel dist 5 0.2138999825077029 for n_states 500
# Time taken: 22.070947647094727
# dest [ 1.20256768 -0.19639193  0.32855973  1.33553181 -0.38484585  0.07515077
#   1.02150915 -0.67237128 -0.00817282]
# Avg new dist 1 0.027322599139143932 rel dist 1 0.2869615114351422 for n_states 500
# Avg new dist 5 0.017260112707556743 rel dist 5 0.19197714631531337 for n_states 500
# Time taken: 22.141631603240967
# time taken 21.501461386680603

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SA_Nonlinear')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(10)
evalObject.setNStates(50)

time_taken = 0.0
dests_count = 10
for idx in range(dests_count):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 120

    dest = ref_traj[time_step]
    print(dest)
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/dests_count))
# Out:
# Using TensorFlow backend.
# [-1.53262594 -0.05801321]
# dest [-1.53262594 -0.05801321]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 0.5896870205798019 rel dist 1 0.25277261111437993 for n_states 50
# Avg new dist 10 0.21375172990313274 rel dist 10 0.13280617953446178 for n_states 50
# Time taken: 2.133951425552368
# [ 3.35161592 -1.31664795]
# dest [ 3.35161592 -1.31664795]
# Avg new dist 1 0.9539629798353164 rel dist 1 0.33726811917364025 for n_states 50
# Avg new dist 10 0.6966147615674271 rel dist 10 0.2830455674737289 for n_states 50
# Time taken: 4.206530809402466
# [-2.36057335  0.18997119]
# dest [-2.36057335  0.18997119]
# Avg new dist 1 0.27472200140775693 rel dist 1 0.12240962497927589 for n_states 50
# Avg new dist 10 0.01555215465202299 rel dist 10 0.017168416688802667 for n_states 50
# Time taken: 2.9134087562561035
# [ 0.04826985 -0.19928837]
# dest [ 0.04826985 -0.19928837]
# Avg new dist 1 0.252235543543275 rel dist 1 0.18406461814754663 for n_states 50
# Avg new dist 10 0.17705583117686458 rel dist 10 0.13037644542315913 for n_states 50
# Time taken: 1.7228214740753174
# [ 0.0053878  -0.23861561]
# dest [ 0.0053878  -0.23861561]
# Avg new dist 1 0.22846143130909602 rel dist 1 0.19916480879439835 for n_states 50
# Avg new dist 10 0.134211256106576 rel dist 10 0.12610166051231167 for n_states 50
# Time taken: 1.6263270378112793
# [-3.44523969  0.14581536]
# dest [-3.44523969  0.14581536]
# Avg new dist 1 0.4061563113726104 rel dist 1 0.12345919140396842 for n_states 50
# Avg new dist 10 0.0675697950145745 rel dist 10 0.02737132347751367 for n_states 50
# Time taken: 3.5897438526153564
# [-2.0921405  0.0164698]
# dest [-2.0921405  0.0164698]
# Avg new dist 1 0.18441283985412205 rel dist 1 0.09780856617268037 for n_states 50
# Avg new dist 10 0.09827398326709527 rel dist 10 0.0667727267209339 for n_states 50
# Time taken: 2.728588342666626
# [2.02198549 0.03543247]
# dest [2.02198549 0.03543247]
# Avg new dist 1 0.5479804201972321 rel dist 1 0.25980567903568375 for n_states 50
# Avg new dist 10 0.2969841450757274 rel dist 10 0.19346219327656783 for n_states 50
# Time taken: 2.822166919708252
# [-1.96937319  0.35804287]
# dest [-1.96937319  0.35804287]
# Avg new dist 1 0.35678115662940807 rel dist 1 0.16122418894435334 for n_states 50
# Avg new dist 10 0.03384716000869461 rel dist 10 0.034132118525133294 for n_states 50
# Time taken: 2.962261199951172
# [ 4.55159496 -0.44521525]
# dest [ 4.55159496 -0.44521525]
# Avg new dist 1 0.7474763172568999 rel dist 1 0.17390505815370522 for n_states 50
# Avg new dist 10 0.5669686480112038 rel dist 10 0.15130471360782127 for n_states 50
# Time taken: 4.71857213973999
# time taken 2.945451092720032

# %%
import matplotlib
# %matplotlib inline
import numpy as np

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SpikingNeuron')
dataObject = evalObject.setDataObject()
#dataObject.setLowerBound([-65, -0.2])
#dataObject.setUpperBound([-60, 0.2])
evalObject.setIterCount(10)
evalObject.setNStates(5)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 337

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
# Out:
# dest [-63.23700742  21.33600432]
# pred init state [-6.36498943e+01 -5.59957183e-02], pred dest state [-63.25415014  21.35870765] distance 0.02844844595611912
# pred init state [-6.36399161e+01 -5.55608455e-02], pred dest state [-63.25450417  21.3591766 ] distance 0.029036028698631474
# pred init state [-6.36467625e+01 -5.67431474e-02], pred dest state [-63.25373249  21.35815443] distance 0.027755279067539815
# pred init state [-6.36504443e+01 -5.61203171e-02], pred dest state [-63.25407043  21.35860207] distance 0.028316158816286154
# pred init state [-6.36422734e+01 -5.53147473e-02], pred dest state [-63.25462919  21.3593422 ] distance 0.029243527237996666
# Avg Relative distance 0.1828701060797975 for n_states 5

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='DampedOsc')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(10)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 11

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# dest [-5.17104307  0.99084549]
# Avg new dist 1 0.056843109012957804 rel dist 1 0.1517450769640908 for n_states 10
# Avg new dist 5 0.03074369657094029 rel dist 5 0.09002104752961496 for n_states 10
# Time taken: 7.829693555831909
# dest [-5.6491765   1.28544412]
# Avg new dist 1 0.1295804676195713 rel dist 1 0.21043550901658586 for n_states 10
# Avg new dist 5 0.03246750621109187 rel dist 5 0.06094578682385349 for n_states 10
# Time taken: 8.045848369598389
# dest [-5.07886871  1.36691648]
# Avg new dist 1 0.07138678578152033 rel dist 1 0.2535869782944625 for n_states 10
# Avg new dist 5 0.027419304679686222 rel dist 5 0.16317522731161943 for n_states 10
# Time taken: 7.81612491607666
# dest [-5.77537   1.523242]
# Avg new dist 1 0.16778976093822814 rel dist 1 0.23770723776916453 for n_states 10
# Avg new dist 5 0.01579025908541535 rel dist 5 0.02518179137150341 for n_states 10
# Time taken: 8.808797597885132
# dest [-5.25221298  0.72077048]
# Avg new dist 1 0.0660389529293233 rel dist 1 0.13751087639110965 for n_states 10
# Avg new dist 5 0.03642327702653908 rel dist 5 0.0871954562293659 for n_states 10
# Time taken: 8.583199977874756
# dest [-5.11987152  0.95930854]
# Avg new dist 1 0.06318827637684944 rel dist 1 0.16362330420555193 for n_states 10
# Avg new dist 5 0.032942563918000364 rel dist 5 0.1031322963446315 for n_states 10
# Time taken: 8.374037504196167
# dest [-5.15744149  1.26135243]
# Avg new dist 1 0.0761521536316823 rel dist 1 0.17505121014338626 for n_states 10
# Avg new dist 5 0.0300607266708074 rel dist 5 0.07746470778438258 for n_states 10
# Time taken: 8.354529857635498
# dest [-5.04566043  1.13035616]
# Avg new dist 1 0.050529945249077876 rel dist 1 0.20325122810600935 for n_states 10
# Avg new dist 5 0.030702495955439335 rel dist 5 0.15281265042184905 for n_states 10
# Time taken: 8.75300908088684
# dest [-5.38659824  1.57342187]
# Avg new dist 1 0.13800912960858114 rel dist 1 0.21116020122104645 for n_states 10
# Avg new dist 5 0.02659547241965789 rel dist 5 0.04502138063185011 for n_states 10
# Time taken: 8.919403314590454
# dest [-4.91527123  1.2093088 ]
# Avg new dist 1 0.07939845176587478 rel dist 1 0.14063551553602896 for n_states 10
# Avg new dist 5 0.02670989798322974 rel dist 5 0.056415880016926837 for n_states 10
# Time taken: 9.23589277267456
# time taken 8.472592401504517

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='AdaptiveCruiseControl')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(10)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 21

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# dest [ 4.03582627 18.5535814  -3.38733952]
# Avg new dist 1 0.24749942070663028 rel dist 1 0.13045627269759685 for n_states 10
# Avg new dist 5 0.02351181986852028 rel dist 5 0.018351408160130502 for n_states 10
# Time taken: 7.056721210479736
# dest [ 2.89689131 19.58761849 -4.1193935 ]
# Avg new dist 1 0.237845776124252 rel dist 1 0.1444415763812527 for n_states 10
# Avg new dist 5 0.03921258925531142 rel dist 5 0.024859969896596744 for n_states 10
# Time taken: 7.2413859367370605
# dest [ 3.66870079 19.80134849 -4.37772502]
# Avg new dist 1 0.17377773181353376 rel dist 1 0.23390548005930678 for n_states 10
# Avg new dist 5 0.1156818291815959 rel dist 5 0.19436068419162134 for n_states 10
# Time taken: 7.224344730377197
# dest [ 3.17603368 18.2055927  -3.41449628]
# Avg new dist 1 0.23285425529226017 rel dist 1 0.15677874932406669 for n_states 10
# Avg new dist 5 0.08488199361136886 rel dist 5 0.07445840522767942 for n_states 10
# Time taken: 7.172720432281494
# dest [ 4.47330254 18.24133043 -3.02587878]
# Avg new dist 1 0.3502528542327537 rel dist 1 0.1372784244816607 for n_states 10
# Avg new dist 5 0.1362853144545596 rel dist 5 0.060517728668715166 for n_states 10
# Time taken: 7.403372287750244
# dest [ 2.4950605  18.93869339 -3.52859439]
# Avg new dist 1 0.2313175470395953 rel dist 1 0.18140568372317156 for n_states 10
# Avg new dist 5 0.054822173553450274 rel dist 5 0.07022232402549314 for n_states 10
# Time taken: 7.8683881759643555
# dest [ 1.79753947 21.04998555 -5.40800862]
# Avg new dist 1 0.6123728715692149 rel dist 1 0.26768763851830657 for n_states 10
# Avg new dist 5 0.2633322309647612 rel dist 5 0.16795885398204402 for n_states 10
# Time taken: 7.550212621688843
# dest [ 4.04128859 19.33396786 -3.6477817 ]
# Avg new dist 1 0.2239263193115466 rel dist 1 0.15535523826006742 for n_states 10
# Avg new dist 5 0.02365912947495714 rel dist 5 0.024251466465706716 for n_states 10
# Time taken: 7.805346488952637
# dest [ 2.75779257 20.72260618 -4.88222023]
# Avg new dist 1 0.2723601037542891 rel dist 1 0.20889134612779098 for n_states 10
# Avg new dist 5 0.08211183083124952 rel dist 5 0.08250452635940794 for n_states 10
# Time taken: 7.723749876022339
# dest [ 2.96037211 20.75143694 -5.04552462]
# Avg new dist 1 0.3139115173990533 rel dist 1 0.17849884727482734 for n_states 10
# Avg new dist 5 0.09229714760337528 rel dist 5 0.07756016903740612 for n_states 10
# Time taken: 8.399823427200317
# time taken 7.5455564022064205

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='OscParticle')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(10)

time_taken = 0.0
for idx in range(10):
    start = time.time()
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    time_step = 21

    dest = ref_traj[time_step]
    dests = [dest]
    evalObject.reachDest(dests=dests, d_time_steps=[time_step], threshold=0.001)
    time_taken += time.time() - start
print("time taken {}".format(time_taken/10))
# Out:
# Using TensorFlow backend.
# dest [0.79200744 0.8378963  1.698882  ]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Avg new dist 1 0.21502232919296765 rel dist 1 0.15463219554538615 for n_states 10
# Avg new dist 5 0.032694926792263684 rel dist 5 0.02670094548611967 for n_states 10
# Time taken: 0.5640177726745605
# dest [-0.76902422  1.41438955  1.51439103]
# Avg new dist 1 0.15420006074910442 rel dist 1 0.11042867344399501 for n_states 10
# Avg new dist 5 0.07071396478471752 rel dist 5 0.051612297775289306 for n_states 10
# Time taken: 0.5051076412200928
# dest [0.06330271 1.52806922 0.01839913]
# Avg new dist 1 0.21924723129175788 rel dist 1 0.1502081863804961 for n_states 10
# Avg new dist 5 0.06012365069063937 rel dist 5 0.044227257982900184 for n_states 10
# Time taken: 0.5910861492156982
# dest [-0.87408078  0.28320364  1.49501907]
# Avg new dist 1 0.20113092933761526 rel dist 1 0.21103817825558457 for n_states 10
# Avg new dist 5 0.10225792416799691 rel dist 5 0.12240200619930061 for n_states 10
# Time taken: 0.5779035091400146
# dest [-0.37696349  1.72202983  0.10915392]
# Avg new dist 1 0.21343777771644284 rel dist 1 0.13887272943938306 for n_states 10
# Avg new dist 5 0.05391250833623547 rel dist 5 0.03705606698246336 for n_states 10
# Time taken: 0.6108598709106445
# dest [-1.03725412  0.52142455  0.5134301 ]
# Avg new dist 1 0.19508852603164556 rel dist 1 0.17218308664878879 for n_states 10
# Avg new dist 5 0.09282974076666561 rel dist 5 0.08487702051154608 for n_states 10
# Time taken: 0.6960952281951904
# dest [0.22908287 2.01222747 0.13543164]
# Avg new dist 1 0.20398811194836525 rel dist 1 0.136319799281937 for n_states 10
# Avg new dist 5 0.053126293900319047 rel dist 5 0.03791837941543048 for n_states 10
# Time taken: 0.6859233379364014
# dest [-0.20055697  1.56050005  1.23100106]
# Avg new dist 1 0.17998724350493112 rel dist 1 0.13381608599270395 for n_states 10
# Avg new dist 5 0.030023876697144836 rel dist 5 0.0250080471906518 for n_states 10
# Time taken: 0.7424824237823486
# dest [-0.68462597  0.0239226   1.38683149]
# Avg new dist 1 0.20597526220676676 rel dist 1 0.1360281238792404 for n_states 10
# Avg new dist 5 0.06186537327840478 rel dist 5 0.04385425505229267 for n_states 10
# Time taken: 0.8673527240753174
# dest [0.08932487 0.5898137  0.478999  ]
# Avg new dist 1 0.15227541911235948 rel dist 1 0.12671786572393048 for n_states 10
# Avg new dist 5 0.057363737916164594 rel dist 5 0.05123676852784835 for n_states 10
# Time taken: 0.8996436595916748
# time taken 0.6745337963104248
