# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([4.0, 4.0]) 
dataObject.setUpperBound([7.0, 7.0])
evalObject.setIterCount(5)

evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.46])
u_states = evalObject.generateRandomUnsafeStates(10)
time_step = 131
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# No handles with labels found to put in legend.
# [array([4.67016061, 6.34469281]), array([5.06611328, 4.58877478])] [0.3985019221170219, 0.004515169110106264]
# Destination [3.1439398459155528, 0.4501499979709376] Ref state [4.67016061 6.34469281] Pred Init state [5.06611328 4.58877478] Pred Dest state [3.14423909 0.44564476] Distance 0.004515169110106264
# Time taken: 1.4048597812652588

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()

dataObject.setLowerBound([2.0, 2.0]) 
dataObject.setUpperBound([2.5, 2.5])
evalObject.setUnsafeSet([1.85, -0.65], [1.92, -0.6])
evalObject.setIterCount(5)

u_states = evalObject.generateRandomUnsafeStates(10)

time_step = 131
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# No handles with labels found to put in legend.
# [array([2.17588909, 2.00327287]), array([2.000001  , 2.04639626])] [0.1450076720567324, 0.02232914431102816]
# Destination [1.9069114485695609, -0.6091163497215686] Ref state [2.17588909 2.00327287] Pred Init state [2.000001   2.04639626] Pred Dest state [ 1.9292327  -0.60970983] Distance 0.02232914431102816
# Time taken: 0.9071555137634277

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lacoperon')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])
evalObject.setIterCount(5)

evalObject.setUnsafeSet([5.6, 27.0], [5.8, 27.5])
u_states = evalObject.generateRandomUnsafeStates(10)
time_step = 301
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# No handles with labels found to put in legend.
# [array([9.36990072, 9.6695799 ]), array([9.16576134, 8.59654442])] [0.022227947555110598, 0.017183302563882515]
# Destination [5.703338310882151, 27.06904053853638] Ref state [9.36990072 9.6695799 ] Pred Init state [9.16576134 8.59654442] Pred Dest state [ 5.70135035 27.08610846] Distance 0.017183302563882515
# Time taken: 0.8539056777954102

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SA_Nonlinear')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(1)

# evalObject.setUnsafeSet([1.20, -1.28], [1.25, -1.24])
# evalObject.setUnsafeSet([4.64, -1.3], [4.7, -1.25])
evalObject.setUnsafeSet([3.2, -1.35], [3.7, -1.25])
u_states = evalObject.generateRandomUnsafeStates(10)
# print(u_states)
time_step = 120
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# No handles with labels found to put in legend.
# [array([-0.54505521, -0.03303981]), array([ 0.14132589, -0.86582607])] [5.618237574064552, 0.1934733243005694]
# Destination [3.4092880329940574, -1.2560626812993418] Ref state [-0.54505521 -0.03303981] Pred Init state [ 0.14132589 -0.86582607] Pred Dest state [ 3.21674372 -1.2371256 ] Distance 0.1934733243005694
# Time taken: 1.2812397480010986

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Buckling')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)

evalObject.setUnsafeSet([-4.5, -38.0], [-3.0, -37.0])
u_states = evalObject.generateRandomUnsafeStates(10)
time_step = 131
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.01)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# No handles with labels found to put in legend.
# [array([6.91383461, 4.5753642 ]), array([8.54303078, 7.10160789]), array([7.8192601 , 8.57614932]), array([8.27649684, 7.19568095]), array([8.22366263, 6.40812811])] [14.476915084558058, 4.6953015540856935, 3.269004138396036, 0.41905404234155397, 0.2542664135196714]
# Destination [-4.024849060457078, -37.48142888155624] Ref state [6.91383461 4.5753642 ] Pred Init state [8.22366263 6.40812811] Pred Dest state [ -4.00824006 -37.73515225] Distance 0.2542664135196714
# Time taken: 1.6359570026397705

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lorentz')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)

evalObject.setUnsafeSet([-6.9, -9.8, 19.0], [-6.4, -9.3, 19.5])
u_states = evalObject.generateRandomUnsafeStates(10)
time_step = 131
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.01)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# No handles with labels found to put in legend.
# [array([2.09729683, 6.93971699, 6.68054047]), array([5.4929173 , 4.21010315, 6.14646049])] [0.4440314209528315, 0.11967349569799289]
# Destination [-6.5716723306484734, -9.459541526452353, 19.158873665093015] Ref state [2.09729683 6.93971699 6.68054047] Pred Init state [5.4929173  4.21010315 6.14646049] Pred Dest state [-6.49560694 -9.38652351 19.21547907] Distance 0.11967349569799289
# Time taken: 1.6395277976989746
