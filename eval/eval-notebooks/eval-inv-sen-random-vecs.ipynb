# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(1)
evalObject.setNStates(20)

time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lotka')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Jetengine')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lacoperon')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='HybridLinearOscillator')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SmoothHybridLinearOscillator')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Roesseler')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lorentz')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Steam')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='CoupledVanderpol')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,50,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (10, 16, 2)
# (10, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='MC')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,25,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# (5, 16, 2)
# (5, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Quadrotor')
dataObject = evalObject.setDataObject()
time_step = 25
d_time_steps = []
for val in range(0,25,5):
    d_time_steps.append(time_step+val)
evalObject.evaluateRandomVecsInv(d_time_steps)
# Out:
# (5, 16, 2)
# (5, 16, 2)
# [ 1.          1.1659144   1.35935639  1.58489319  1.8478498   2.15443469
#   2.51188643  2.92864456  3.41454887  3.98107171  4.64158883  5.41169527
#   6.30957344  7.35642254  8.57695899 10.        ]
