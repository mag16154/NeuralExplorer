# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([4.0, 4.0]) 
dataObject.setUpperBound([7.0, 7.0])
evalObject.setIterCount(5)

evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.46])
u_states = evalObject.generateRandomUnsafeStates(10)
# print(u_states)
time_step = 131
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# No handles with labels found to put in legend.
# [array([5.65170142, 4.31957754])] [0.008509224535519989]
# Destination [3.2318580155345815, 0.42709005109930603] Ref state [5.65170142 4.31957754] Pred Init state [5.65170142 4.31957754] Pred Dest state [3.22912915 0.43514984] Distance 0.008509224535519989
# Time taken: 1.2114834785461426

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()

dataObject.setLowerBound([2.0, 2.0]) 
dataObject.setUpperBound([2.5, 2.5])
evalObject.setUnsafeSet([1.85, -0.65], [1.92, -0.6])
time_step = 131
evalObject.setIterCount(5)
evalObject.setNStates(1)

u_states = evalObject.generateRandomUnsafeStates(10)

evalObject.reachDest(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# No handles with labels found to put in legend.
# [array([2.23478482, 2.22074507]), array([2.000001  , 2.01496356]), array([2.000001, 2.000001])] [0.24161809231371334, 0.01734330187549155, 0.014312110305574156]
# Destination [1.9113749873132522, -0.6264849234320102] Ref state [2.23478482 2.22074507] Pred Init state [2.000001 2.000001] Pred Dest state [ 1.91777668 -0.61368434] Distance 0.014312110305574156
# Time taken: 1.1722640991210938

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lacoperon')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])
evalObject.setIterCount(5)
evalObject.setNStates(1)

evalObject.setUnsafeSet([5.6, 27.0], [5.8, 27.5])
u_states = evalObject.generateRandomUnsafeStates(10)
# print(u_states)
time_step = 151
evalObject.reachDest(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# No handles with labels found to put in legend.
# [array([9.43487098, 9.967934  ]), array([9.30626956, 8.07210801])] [0.03180498369177841, 0.00956692331456916]
# Destination [5.678043877630721, 27.060887636151655] Ref state [9.43487098 9.967934  ] Pred Init state [9.30626956 8.07210801] Pred Dest state [ 5.67414073 27.06962214] Distance 0.00956692331456916
# Time taken: 2.17044997215271

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SA_Nonlinear')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(1)

# evalObject.setUnsafeSet([1.20, -1.28], [1.25, -1.24])
# evalObject.setUnsafeSet([4.64, -1.3], [4.7, -1.25])
evalObject.setUnsafeSet([3.2, -1.35], [3.7, -1.25])
u_states = evalObject.generateRandomUnsafeStates(10)
# print(u_states)
time_step = 120
evalObject.reachDest(dests=u_states, d_time_steps=[time_step], threshold=0.001)
# Out:
# No handles with labels found to put in legend.
# [array([-0.42974938, -0.02565428]), array([ 0.21408765, -0.8479844 ])] [5.170330004758555, 0.11266630191450436]
# Destination [3.5332456929004934, -1.2898318668668536] Ref state [-0.42974938 -0.02565428] Pred Init state [ 0.21408765 -0.8479844 ] Pred Dest state [ 3.43176969 -1.33878405] Distance 0.11266630191450436
# Time taken: 2.5369675159454346

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Buckling')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(1)

evalObject.setUnsafeSet([-4.5, -38.0], [-3.0, -37.0])
u_states = evalObject.generateRandomUnsafeStates(10)
# print(u_states)
time_step = 131
evalObject.reachDest(dests=u_states, d_time_steps=[time_step], threshold=0.01)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# No handles with labels found to put in legend.
# [array([9.48142687, 5.91676158]), array([8.2477285 , 7.98188276])] [72.91041248020835, 0.1718432830865193]
# Destination [-4.382951689026437, -37.89606004441419] Ref state [9.48142687 5.91676158] Pred Init state [8.2477285  7.98188276] Pred Dest state [ -4.21746868 -37.84974065] Distance 0.1718432830865193
# Time taken: 1.8318419456481934

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lorentz')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)
evalObject.setNStates(1)

evalObject.setUnsafeSet([-6.9, -9.8, 19.0], [-6.4, -9.3, 19.5])
u_states = evalObject.generateRandomUnsafeStates(10)
# print(u_states)
time_step = 131
evalObject.reachDest(dests=u_states, d_time_steps=[time_step], threshold=0.01)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# No handles with labels found to put in legend.
# [array([4.7661627 , 4.8618218 , 5.85177328]), array([5.93786938, 4.000001  , 6.23461433])] [1.0913448413082296, 0.11174178541549101]
# Destination [-6.439670827715147, -9.379215926835755, 19.044669750202992] Ref state [4.7661627  4.8618218  5.85177328] Pred Init state [5.93786938 4.000001   6.23461433] Pred Dest state [-6.39050436 -9.28935041 19.00002591] Distance 0.11174178541549101
# X
# Time taken: 3.2318296432495117
