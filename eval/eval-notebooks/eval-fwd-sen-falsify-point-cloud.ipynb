# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([4.0, 4.0]) 
dataObject.setUpperBound([7.0, 7.0])

# evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.46])
# u_states = evalObject.generateRandomUnsafeStates(10)
# for dest in u_states:
#     print("Destination: {}".format(dest))
#     evalObject.point_clound_fwd_naive(dest=dest)

evalObject.setIterCount(10)
evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.46]) # [4- 7] and 131
# evalObject.setUnsafeSet([10.5, 0.10], [11.5, 0.40]) # [8- 10] and 51

u_states = evalObject.generateRandomUnsafeStates(10)
evalObject.reachDestFwd(dests=u_states, threshold=0.001)
# Out:
# Using TensorFlow backend.
# Time step: 143 ref_state [5.61289551 5.31627974] min_dist 0.018050704839112443
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Time step: 153 ref_state [6.85468972 4.23791852] min_dist 0.0588912011254561
#
# Time step: 138 ref_state [4.5148704  4.63754002] min_dist 0.08839618203587164
#
# Time step: 162 ref_state [6.57779755 6.05061652] min_dist 0.033790736274874604
#
# Time step: 147 ref_state [4.79766921 6.76297596] min_dist 0.01202182207435496
#
# Time step: 148 ref_state [6.07421687 4.76644762] min_dist 0.025248477603596012
#
# Time step: 146 ref_state [6.68833675 5.03683089] min_dist 0.03192633553085703
#
# Time step: 161 ref_state [6.80752144 6.20349888] min_dist 0.034567586102798094
#
# Time step: 135 ref_state [4.90539218 4.9702108 ] min_dist 0.013964711999512807
#
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([1.5, 1.5]) 
dataObject.setUpperBound([3.0, 3.0])

# evalObject.setUnsafeSet([9.5, -0.5], [10, 0.0]) # for [8-10]

evalObject.setIterCount(10)
evalObject.setUnsafeSet([1.5, -1.0], [2.0, -0.6]) #131
u_states = evalObject.generateRandomUnsafeStates(10)
evalObject.reachDestFwd(dests=u_states, threshold=0.01)
# Out:
# Time step: 208 ref_state [2.03854485 2.91676547] min_dist 0.2698141200548501
#
# Time step: 323 ref_state [2.98864269 2.07091259] min_dist 0.11838205555345192
#
# Time step: 205 ref_state [2.17413928 2.41225226] min_dist 0.1186252039111969
#
# Time step: 142 ref_state [1.81354153 1.82775975] min_dist 0.10266513887058404
#
# Time step: 280 ref_state [2.87519052 1.54945219] min_dist 0.19402938144610107
#
# Time step: 276 ref_state [2.61800956 2.99512377] min_dist 0.04619793990527314
#
# Time step: 120 ref_state [1.81354524 2.11123462] min_dist 0.05619781163434607
#
# Time step: 296 ref_state [2.83371854 1.87508455] min_dist 0.017433043630561675
#
# Time step: 294 ref_state [2.61855852 2.51726708] min_dist 0.017376389356197397
#
# Time step: 287 ref_state [2.5837012  2.90687018] min_dist 0.14334284949048343

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Jetengine')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])

evalObject.setIterCount(10)
# evalObject.setUnsafeSet([0.2, -4.0], [0.4, -3.0]) #131
evalObject.setUnsafeSet([-3.0, 4.0], [-2.7, 4.5]) #31
u_states = evalObject.generateRandomUnsafeStates(2)
for dest in u_states:
    print("Destination: {}".format(dest))
    evalObject.reachDestFwd(dests=[dest], threshold=0.01)
# Out:
# Destination: [-2.8870370556431078, 4.019132039682406]
# Time step: 32 ref_state [8.19022096 8.71682258] min_dist 0.14428328020613057
# Destination: [-2.990647175330764, 4.106491142231451]
# Time step: 32 ref_state [8.91812483 9.61376993] min_dist 0.1388308754084202
