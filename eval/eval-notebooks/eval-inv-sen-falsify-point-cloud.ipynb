# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([4.0, 4.0]) 
dataObject.setUpperBound([7.0, 7.0])

evalObject.setIterCount(15)
evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.56])
# evalObject.setUnsafeSet([3.8, 0.39], [4.4, 0.56]) # Try moving the unsafe set
u_states = evalObject.generateRandomUnsafeStates(200)
time_step = 131
# time_step = 111 # Try changing the time step for same unsafe set
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001, plot_point_cloud=True)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# [array([4.30316602, 5.27761961]), array([5.3886268 , 4.28452892]), array([5.90136122, 4.40253835]), array([5.92466246, 4.60691511]), array([5.88763981, 4.62004035]), array([5.87549721, 4.60204034])] [0.24286205953413686, 0.23067532760391007, 0.052850912354662834, 0.012757422033545792, 0.006306593152449647, 0.0029898717985376516]
# Destination [3.3751091087365035, 0.4198442949352671] Ref state [4.30316602 5.27761961] Pred Init state [5.87549721 4.60204034] Pred Dest state [3.3724472  0.41848284] Distance 0.0029898717985376516
# Time taken: 11.610674142837524

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([1.5, 1.5]) 
dataObject.setUpperBound([3.0, 3.0])

evalObject.setIterCount(10)
# evalObject.setUnsafeSet([9.5, -0.3], [10, 0.0])
# time_step = 61

evalObject.setUnsafeSet([1.5, -1.0], [2.0, -0.6])
time_step = 131
#time_step = 201 # Try changing the time
u_states = evalObject.generateRandomUnsafeStates(500)

evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001, plot_point_cloud=True)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# [array([2.20743214, 2.53909035]), array([1.60179483, 1.68406768]), array([1.52603012, 1.59163055])] [0.6788392961647232, 0.06699385918370035, 0.0005829930349400698]
# Destination [1.530680836199958, -0.7228691155065212] Ref state [2.20743214 2.53909035] Pred Init state [1.52603012 1.59163055] Pred Dest state [ 1.5310424  -0.72241178] Distance 0.0005829930349400698
# Time taken: 13.345131158828735
