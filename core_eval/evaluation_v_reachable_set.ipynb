# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])
evalObject.compute_bkd_reachableSet(time_bound = 300)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([0.5, 0.5]) 
dataObject.setUpperBound([3.0, 3.0])
evalObject.compute_bkd_reachableSet(time_bound = 400)
# Out:
# 0.1

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Jetengine')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])
evalObject.compute_bkd_reachableSet(time_bound = 300)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lotka')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])
evalObject.compute_bkd_reachableSet(time_bound = 300)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Buckling')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])
evalObject.compute_bkd_reachableSet(time_bound = 300)
# Out:
# Using TensorFlow backend.
# 0.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lacoperon')
dataObject = evalObject.setDataObject()
dataObject.setTimeStep(0.2)
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])
evalObject.compute_bkd_reachableSet(time_bound = 300)

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='HybridLinearOscillator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([4.0, 4.0]) 
dataObject.setUpperBound([6.0, 6.0])
evalObject.compute_bkd_reachableSet(time_bound = 300)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# /usr/local/lib/python3.6/dist-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../NNConfiguration_setup/frechet.py:21: RuntimeWarning: overflow encountered in double_scalars
#   square = square + pt[i]*pt[i]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c43fac73992c> in <module>
#      10 dataObject.setLowerBound([4.0, 4.0])
#      11 dataObject.setUpperBound([6.0, 6.0])
# ---> 12 evalObject.compute_bkd_reachableSet(time_bound = 300)
#
# ~/Research/cps-falsification/pyExploreNN/L4DC/evaluation.py in compute_bkd_reachableSet(self, time_bound)
#     689             projected_vp = projected_vps[idx]
#     690             for point in projected_vp:
# --> 691                 ax1.scatter(point[0], point[1], color='red')
#     692         ax1.set_xlabel('x1')
#     693         ax1.set_ylabel('x2')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4324                 self.set_ymargin(0.05)
#    4325
# -> 4326         self.add_collection(collection)
#    4327         self.autoscale_view()
#    4328
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in add_collection(self, collection, autolim)
#    1859
#    1860         if autolim:
# -> 1861             self.update_datalim(collection.get_datalim(self.transData))
#    1862
#    1863         self.stale = True
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py in get_datalim(self, transData)
#     204                 transform.frozen(), paths, self.get_transforms(),
#     205                 offsets, transOffset.frozen())
# --> 206             result = result.inverse_transformed(transData)
#     207         else:
#     208             result = transforms.Bbox.null()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in inverse_transformed(self, transform)
#     536         the inverse of the given transform.
#     537         """
# --> 538         return self.transformed(transform.inverted())
#     539
#     540     coefs = {'C':  (0.5, 0.5),
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in inverted(self)
#    2463     get_affine.__doc__ = Transform.get_affine.__doc__
#    2464
# -> 2465     def inverted(self):
#    2466         return CompositeGenericTransform(self._b.inverted(), self._a.inverted())
#    2467     inverted.__doc__ = Transform.inverted.__doc__
#
# KeyboardInterrupt:

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Roesseler')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0, 10.0])
evalObject.compute_bkd_reachableSet(time_bound = 200)

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lorentz')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0, 8.0])
dataObject.setUpperBound([10.0, 10.0, 10.0])
evalObject.compute_bkd_reachableSet(time_bound = 200)
# Out:
# Using TensorFlow backend.
# 0.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation
    
evalObject = Evaluation(dynamics='Steam')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([2.0, 2.0, 2.0]) 
dataObject.setUpperBound([4.0, 4.0, 4.0])
evalObject.compute_bkd_reachableSet(time_bound = 200)
# Out:
# 0.6

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='LaubLoomis')
dataObject = evalObject.setDataObject()
dataObject.setTimeStep(0.1)
dataObject.setLowerBound([1.1, 1.0, 1.4, 2.3, 0.5, 0.05, 0.4])
dataObject.setUpperBound([1.3, 1.1, 1.6, 2.5, 1.5, 0.15, 0.5])
evalObject.compute_bkd_reachableSet(time_bound = 150)
# Out:
# Using TensorFlow backend.
# 0.05
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Quadrotor')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([0.00, 0.00, 0.0, 0.0, 0.0, 0.0])
dataObject.setUpperBound([0.20, 0.20, 0.0, 0.0, 0.0, 0.0])
evalObject.compute_bkd_reachableSet(time_bound = 100)
# Out:
# Using TensorFlow backend.
# 0.05
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='MC')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([-0.55, 0.0])
dataObject.setUpperBound([-0.45, 0.0])
evalObject.compute_bkd_reachableSet(time_bound = 99)
# Out:
# Using TensorFlow backend.
# 0.01
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
