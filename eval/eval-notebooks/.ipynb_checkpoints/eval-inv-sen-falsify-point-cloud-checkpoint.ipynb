# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([4.0, 4.0]) 
dataObject.setUpperBound([7.0, 7.0])

evalObject.setIterCount(15)
evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.56])
# evalObject.setUnsafeSet([3.8, 0.39], [4.4, 0.56]) # Try moving the unsafe set
u_states = evalObject.generateRandomUnsafeStates(200)
time_step = 131
# time_step = 111 # Try changing the time step for same unsafe set
evalObject.reachDestInv(dests=u_states, d_time_steps=[time_step], threshold=0.001, plot_point_cloud=True)
# Out:
# [array([4.14018068, 5.81075979]), array([4.60428134, 4.16182674])] [0.449042063454138, 0.029138076756656726]
# Destination [3.3564863853955442, 0.40148845563378666] Ref state [4.14018068 5.81075979] Pred Init state [4.60428134 4.16182674] Pred Dest state [3.38079804 0.41754993] Distance 0.029138076756656726
# 13
# 115
# 43
# 82
# 19
# 37
# 35
# 32
# 44
# 158
# Time taken: 23.604509353637695

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([1.5, 1.5]) 
dataObject.setUpperBound([3.0, 3.0])

evalObject.setIterCount(10)
evalObject.setNStates(1)
# evalObject.setUnsafeSet([9.5, -0.3], [10, 0.0])
# time_step = 61

evalObject.setUnsafeSet([1.5, -1.0], [2.0, -0.6])
time_step = 131
#time_step = 201 #If time needs to change
u_states = evalObject.generateRandomUnsafeStates(500)
# print(u_states)

evalObject.reachDest(dests=u_states, d_time_steps=[time_step], threshold=0.001, plot_point_cloud=True)
# Out:
# [array([1.51623565, 2.65003082]), array([2.25622267, 1.92709699]), array([2.17649278, 2.48923745])] [0.4412099073611002, 0.08251987340168714, 0.0039260882290766495]
# Destination [1.721403093314424, -0.7124159732021362] Ref state [1.51623565 2.65003082] Pred Init state [2.17649278 2.48923745] Pred Dest state [ 1.71790421 -0.71063497] Distance 0.0039260882290766495
# 185
# 227
# 182
# 125
# 86
# 88
# 71
# 56
# 21
# 23
# Time taken: 16.19165563583374
