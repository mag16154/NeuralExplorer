# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([4.0, 4.0]) 
dataObject.setUpperBound([7.0, 7.0])

# evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.46])
# u_states = evalObject.generateRandomUnsafeStates(10)
# for dest in u_states:
#     print("Destination: {}".format(dest))
#     evalObject.point_clound_fwd_naive(dest=dest)

evalObject.setIterCount(10)
evalObject.setUnsafeSet([2.8, 0.39], [3.4, 0.46]) # [4- 7] and 131
# evalObject.setUnsafeSet([10.5, 0.10], [11.5, 0.40]) # [8- 10] and 51

u_states = evalObject.generateRandomUnsafeStates(10)
evalObject.reachDest_fwd(dests=u_states, threshold=0.001)
# Out:
# Using TensorFlow backend.
# Time step: 129 ref_state [4.68425191 4.71013189] min_dist 0.01371524235876949
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Time step: 143 ref_state [5.10594012 6.47650331] min_dist 0.035459536351546375
#
# Time step: 131 ref_state [4.36059501 5.53508372] min_dist 0.038990883256339946
#
# Time step: 149 ref_state [5.30126391 6.74619883] min_dist 0.019790047563891813
#
# Time step: 166 ref_state [5.91596126 6.44184149] min_dist 0.060810042069903134
#
# Time step: 151 ref_state [6.79753939 5.4490003 ] min_dist 0.01133034878845145
#
# Time step: 164 ref_state [4.99249559 6.62257202] min_dist 0.05229906127203275
#
# Time step: 125 ref_state [4.44838004 4.48396835] min_dist 0.014204585489260051
#
# Time step: 164 ref_state [6.49576185 6.05817512] min_dist 0.03806202714620894
#
# Time step: 122 ref_state [4.94018532 4.3815439 ] min_dist 0.008740142858129508

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([1.5, 1.5]) 
dataObject.setUpperBound([3.0, 3.0])

# evalObject.setUnsafeSet([9, -0.3], [10, 0.0])
# u_states = evalObject.generateRandomUnsafeStates(10)
# for dest in u_states:
#     evalObject.point_cloud_fwd_naive(dest=dest)
# evalObject.setUnsafeSet([9.5, -0.5], [10, 0.0]) # for [8-10]

evalObject.setIterCount(10)
evalObject.setUnsafeSet([1.5, -1.0], [2.0, -0.6]) #131
u_states = evalObject.generateRandomUnsafeStates(10)
#for dest in u_states:
#    print("Destination: {}".format(dest))
evalObject.reachDest_fwd(dests=u_states, threshold=0.001)
# Out:
# Using TensorFlow backend.
# Time step: 303 ref_state [2.69056406 2.98313355] min_dist 0.23713112608314485
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Time step: 178 ref_state [2.17704754 2.13153455] min_dist 0.3027520428126541
#
# Time step: 170 ref_state [2.21574457 2.03839622] min_dist 0.31192279350768654
#
# Time step: 354 ref_state [2.84557206 2.91831093] min_dist 0.09088655942303243
#
# Time step: 139 ref_state [1.63579227 1.71294717] min_dist 0.17091576791989
#
# Time step: 151 ref_state [1.58978497 2.98008385] min_dist 0.19613765815899872
#
# Time step: 271 ref_state [2.7131704  2.54910042] min_dist 0.04621023000421471
#
# Time step: 203 ref_state [2.16369147 1.81065432] min_dist 0.04515594650997563
#
# Time step: 174 ref_state [1.72641756 2.39571259] min_dist 0.037893831544390834
#
# Time step: 186 ref_state [1.83576146 2.60106571] min_dist 0.19740003431460765

# %%
import matplotlib
# %matplotlib inline
import numpy as np
import time

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Jetengine')
dataObject = evalObject.setDataObject()
dataObject.setLowerBound([8.0, 8.0]) 
dataObject.setUpperBound([10.0, 10.0])

evalObject.setIterCount(10)
#evalObject.setUnsafeSet([-3.2, -0.8], [-3.0, -0.7])
# evalObject.setUnsafeSet([0.2, -4.0], [0.4, -3.0]) #131
evalObject.setUnsafeSet([-3.0, 4.0], [-2.7, 4.5]) #31
u_states = evalObject.generateRandomUnsafeStates(1)
for dest in u_states:
    print("Destination: {}".format(dest))
    evalObject.reachDest_fwd(dests=[dest], threshold=0.01)
# Out:
# Destination: [-2.8658390824753774, 4.209862243411839]
# Time step: 32 ref_state [9.71115365 9.96753983] min_dist 0.3469208569028606
