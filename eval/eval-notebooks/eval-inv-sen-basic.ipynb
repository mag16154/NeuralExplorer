# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Brussellator')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(3)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49
#print(ref_traj[0], ref_traj[time_step])

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [11.20610574  0.13289368]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [9.89802321 8.18560802], pred dest state [11.40510122  0.13060584] distance 0.1990086339117192
# Iteration 1: pred init state [8.58422807 9.34197216], pred dest state [11.31737921  0.13160465] distance 0.11128093697839692
# Time taken: 1.0989031791687012

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lotka')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [2.65252451 1.23747433]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [2.16149269 1.0219335 ], pred dest state [2.92985198 0.80140519] distance 0.5167850742181449
# Iteration 1: pred init state [2.43160044 1.58951474], pred dest state [2.56720548 1.22066459] distance 0.08695921346126409
# Time taken: 1.207566261291504

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Jetengine')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [-1.77247942 -0.05566581]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [2.93541607 9.83253724], pred dest state [-3.23900734 -0.45993911] distance 1.5212301083776867
# Iteration 1: pred init state [1.40979441 3.7060085 ], pred dest state [-2.29992083 -0.47100554] distance 0.6713430853740546
# Iteration 2: pred init state [1.54293553 2.99678594], pred dest state [-1.86734762 -0.12740707] distance 0.11894026021925273
# Iteration 3: pred init state [1.49058205 2.89175237], pred dest state [-1.8092418  -0.12002767] distance 0.07412099857145057
# Time taken: 0.778252124786377

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Vanderpol')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [0.27938201 0.15926747]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [0.92515439 1.15635015], pred dest state [1.34131234 0.46252956] distance 1.1043839490057614
# Iteration 1: pred init state [0.24387103 0.23237068], pred dest state [0.34859567 0.18164757] distance 0.07274200333783266
# Time taken: 0.765592098236084

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lacoperon')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# dest [10.13345869 23.03371465]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [9.26898961 0.77903525], pred dest state [10.18108666 22.84776329] distance 0.1919539808845949
# Iteration 1: pred init state [9.71110951 5.0651342 ], pred dest state [10.13424061 23.01821148] distance 0.015522874644623612
# Time taken: 0.7552313804626465

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='HybridLinearOscillator')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [ 8.80933954 -0.48078883]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [5.92185135 5.68482903], pred dest state [ 8.01984019 -1.7515041 ] distance 1.4960035239716796
# Iteration 1: pred init state [5.04976215 6.72794894], pred dest state [ 8.40037523 -0.44619497] distance 0.4104248325036533
# Time taken: 1.0717647075653076

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SmoothHybridLinearOscillator')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1,basic=True)
# Out:
# Using TensorFlow backend.
# dest [5.32682495 2.24264874]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [5.62464858 0.32214821], pred dest state [ 3.4408069  -4.46108796] distance 6.963989509191469
# Iteration 1: pred init state [1.27497865 4.64032161], pred dest state [4.45555936 1.81828101] distance 0.9691190315215565
# Iteration 2: pred init state [1.06321179 5.38281179], pred dest state [4.90731751 2.4542447 ] distance 0.46985034137273823
# Iteration 3: pred init state [1.15370571 5.37266924], pred dest state [4.96769671 2.34917022] distance 0.37459300544335905
# Iteration 4: pred init state [1.20116656 5.37274518], pred dest state [5.00298184 2.29768677] distance 0.32848675437328767
# Time taken: 1.3306922912597656

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Roesseler')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# dest [-4.12134194  7.81011256  0.03967373]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [8.59827214 3.59625459 1.51449926], pred dest state [-0.391413    9.36573446  0.50505329] distance 4.068034848445058
# Iteration 1: pred init state [5.44053202 5.91392279 5.08435829], pred dest state [-3.86969821  7.86650378  0.05384559] distance 0.2582738402826362
# Time taken: 0.7463889122009277

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Lorentz')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [-2.02735692 -6.1732276  26.38164746]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [1.34121008 4.31767526 3.07047879], pred dest state [-2.81504892 -7.33025254 27.25739745] distance 1.6510915932696448
# Iteration 1: pred init state [2.72026189 2.49154963 5.52859794], pred dest state [-1.07380134 -6.13529232 27.4906535 ] distance 1.4630795353144406
# Iteration 2: pred init state [2.80888399 3.22997382 5.23740654], pred dest state [-1.83826239 -6.16042016 26.60097722] distance 0.28987292874418147
# Time taken: 1.2175347805023193

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Steam')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# dest [ 1.4821005   0.87436678 -0.27729098]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [1.57096345 3.85910277 3.19796131], pred dest state [3.11759906 2.57070961 2.37822077] distance 3.5502362116837363
# Iteration 1: pred init state [1.31429619 1.77037148 0.68101929], pred dest state [2.18355083 1.76931577 0.10677084] distance 1.2001957101282026
# Iteration 2: pred init state [1.57627547 1.26501458 0.46955268], pred dest state [ 2.1948066   1.26064458 -0.16981873] distance 0.8177474027296632
# Iteration 3: pred init state [1.59150022 1.1566806  0.52761087], pred dest state [ 2.15626935  1.15045517 -0.10683658] distance 0.7481865688402536
# Time taken: 0.8081848621368408

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Rober')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [4.08195997e+00 1.73953391e-06 9.38111172e+00]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [4.95779895 8.92708889 3.56937246], pred dest state [4.98638832e+00 1.59914090e-06 1.24678704e+01] distance 3.2165306990236355
# Iteration 1: pred init state [4.17575186 8.94472911 1.69379132], pred dest state [4.20017143e+00 1.58215743e-06 1.06140993e+01] distance 1.2386412934683944
# Iteration 2: pred init state [4.75386375 7.9018773  2.33865784], pred dest state [4.77715287e+00 1.86920557e-06 1.02172442e+01] distance 1.087387060371707
# Iteration 3: pred init state [4.35348784 8.14480654 1.3948028 ], pred dest state [4.37522508e+00 1.83767678e-06 9.51787027e+00] distance 0.32358510864211826
# Time taken: 1.1253647804260254

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='CoupledVanderpol')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [ 1.64938477 -0.2414265   1.45326136  0.92871381]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [1.67254394 0.97705546 1.51030339 0.70427316], pred dest state [ 1.80277329 -0.25342078  1.62279769 -0.15298106] distance 1.105657392150733
# Iteration 1: pred init state [2.39223013e+00 1.00000000e-06 5.60209825e-01 1.00000000e-06], pred dest state [ 2.12200126 -0.83437525  0.71595538  0.61302717] distance 1.1037358042560408
# Time taken: 1.236940860748291

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='LaubLoomis')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.01, basic=True)
# Out:
# Using TensorFlow backend.
# dest [0.566828   0.22733445 0.36036375 3.91701302 0.10478264 0.05603372
#  0.20741388]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [1.13402441 1.07318759 1.59020319 2.45662339 1.20474876 0.07964824
#  0.46078463], pred dest state [0.49585546 0.17669313 0.33161305 4.3654705  0.0807277  0.04842804
#  0.19920947] distance 0.45852607292616204
# Iteration 1: pred init state [1.16696953 1.03602777 1.49131222 2.499999   0.73530886 0.1064445
#  0.45315385], pred dest state [0.55546005 0.22473219 0.35111943 3.97499724 0.10146761 0.05505816
#  0.20429894] distance 0.060043932855567195
# Iteration 2: pred init state [1.15329813 1.03073026 1.46556622 2.499999   0.6851249  0.11237068
#  0.45230547], pred dest state [0.56550711 0.23177386 0.35551113 3.91740451 0.105056   0.05611235
#  0.20544476] distance 0.007008048273406012
# Time taken: 1.4487779140472412

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='MC')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.01, basic=True)
# Out:
# Using TensorFlow backend.
# dest [-1.13877309e+00  3.05261221e-04]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [-0.47118289  0.        ], pred dest state [-1.11550316  0.00131237] distance 0.023291712074718682
# Iteration 1: pred init state [-0.46344105  0.        ], pred dest state [-1.13490467e+00  4.78053490e-04] distance 0.0038722704809628387
# Time taken: 0.8806335926055908

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='Quadrotor')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(4)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 89

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.01, basic=True)
# Out:
# Using TensorFlow backend.
# dest [ 0.09823158  0.25064639 -0.722       0.87601199 -0.87601199 -1.06      ]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [0.0662475  0.15777172 0.         0.         0.         0.        ], pred dest state [-0.20315639  0.0258849   0.7832      0.62009837 -0.20669946  1.78      ] distance 3.3145211590138848
# Iteration 1: pred init state [0.15257601 0.18742458 0.         0.         0.         0.        ], pred dest state [ 0.09302128  0.2469793  -0.722       0.87601199 -0.87601199 -1.06      ] distance 0.006371394760586997
# Time taken: 1.4724009037017822

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='BiologicalModel1')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.1, basic=True)
# Out:
# Using TensorFlow backend.
# dest [2.85598945 1.13198699 0.32614985 0.73981648 1.10172554 0.24661149
#  2.7763997 ]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [1.29405753 1.92513751 2.05185396 2.072463   1.85516394 1.64716024
#  0.33734705], pred dest state [3.40424631 1.41607941 0.45072328 0.55017027 3.37745667 0.05733495
#  1.92717233] distance 2.5236369038450177
# Iteration 1: pred init state [0.89697026 1.48444457 2.099999   1.1911166  0.86383624 1.44778602
#  1.80208053], pred dest state [3.03854041 1.20447125 0.23840217 1.0482031  1.00674974 0.28529891
#  2.96456764] distance 0.432787560183082
# Iteration 2: pred init state [0.98234948 1.61641105 1.97026276 1.25290986 0.42987446 1.00890933
#  1.99562824], pred dest state [2.98827274 1.1880564  0.39269415 0.63863461 1.04414971 0.25889247
#  2.7456451 ] distance 0.19929929081022618
# Time taken: 1.5058231353759766

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='VehiclePlatoon')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 157

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.01, basic=True)
# Out:
# Using TensorFlow backend.
# dest [ 1.05461644 -0.33194945  0.12488835  1.0800178  -0.27267851  0.08796479
#   0.68174383 -0.52637266 -0.28121745]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [1.05869304 0.98498376 1.06478483 1.07524638 1.05084051 0.92452579
#  0.98957863 1.004913   0.92836687], pred dest state [ 1.14854957 -0.35872728  0.14152678  1.20341585 -0.31833387  0.07855171
#   0.70400434 -0.53010446 -0.2924381 ] distance 0.1668915148798593
# Iteration 1: pred init state [0.98443442 0.99457389 1.07480388 0.96092249 0.94304323 1.07707871
#  1.02532003 0.90352937 0.92938663], pred dest state [ 1.07787941 -0.34208322  0.12199389  1.10391581 -0.28335833  0.08865826
#   0.6678367  -0.5101018  -0.28303347] distance 0.042418604222227346
# Iteration 2: pred init state [0.9725794  1.00194869 1.08176093 0.96064859 0.93242204 1.09987229
#  1.03007419 0.90185309 0.93923889], pred dest state [ 1.07383823 -0.3409573   0.12133154  1.09755853 -0.28032447  0.08987414
#   0.66716482 -0.51164551 -0.28339858] distance 0.03559840486723555
# Iteration 3: pred init state [0.9679398  1.00152862 1.08512217 0.96691206 0.92949841 1.09973754
#  1.03796504 0.900001   0.93884945], pred dest state [ 1.07346886 -0.34032801  0.12239301  1.0982371  -0.27985732  0.09012543
#   0.66636086 -0.51372211 -0.28462831] distance 0.03504701869900214
# Iteration 4: pred init state [0.96564683 1.00271232 1.08553089 0.96804156 0.92824719 1.099999
#  1.03947654 0.900001   0.93687839], pred dest state [ 1.07324574 -0.34017268  0.12256366  1.09820101 -0.27960453  0.0903363
#   0.66655811 -0.51441836 -0.28482859] distance 0.0345087092607979
# Iteration 5: pred init state [0.96513906 1.00257981 1.08595575 0.96885462 0.9274311  1.099999
#  1.0403284  0.900001   0.93693389], pred dest state [ 1.07313455 -0.34008877  0.12265755  1.09811458 -0.27948151  0.09038874
#   0.66647224 -0.51468297 -0.28497745] distance 0.03431913624241946
# Time taken: 1.6584465503692627

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='SpikingNeuron')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 337

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.01, basic=True)
# Out:
# Using TensorFlow backend.
# dest [-62.991156    21.31161724]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Iteration 0: pred init state [-62.22247563  -0.18964819], pred dest state [-62.93316517  21.20009884] distance 0.12569522121527163
# Iteration 1: pred init state [-62.15902134  -0.11400752], pred dest state [-63.08159366  21.28466271] distance 0.094369050325497
# Iteration 2: pred init state [-61.68509964  -0.11227322], pred dest state [-63.03637865  21.27633613] distance 0.057357167239821615
# Time taken: 1.1198530197143555

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import sys
sys.path.append('../../core')
sys.path.append('../../configuration-setup/')

from evaluation import Evaluation

evalObject = Evaluation(dynamics='DampedOsc')
dataObject = evalObject.setDataObject()
evalObject.setIterCount(5)

ref_traj = dataObject.generateTrajectories(samples=1)[0]
time_step = 49

dest = ref_traj[time_step]
dests = [dest]
evalObject.reachDestInv(dests=dests, d_time_steps=[time_step], threshold=0.001, basic=True)
# Out:
# dest [-4.97480487  2.77038088]
# Iteration 0: pred init state [-5.62052995  0.40744896], pred dest state [-4.53944949  2.86099241] distance 0.4446850032943284
# Iteration 1: pred init state [-5.88844424  0.15122087], pred dest state [-4.87935641  2.76578282] distance 0.0955591496629588
# Iteration 2: pred init state [-5.93044856  0.11466201], pred dest state [-4.93102874  2.75389126] distance 0.0467788102795784
# Time taken: 0.6670112609863281
